# %%
import sys, os, json, shap, gc, joblib, time, warnings, copy, ast
import pandas as pd
import numpy as np
import lightgbm as lgb
from lightgbm import LGBMClassifier
import pickle as pkl
from tqdm import tqdm
from smart_open import open
import seaborn as sns
from sklearn.metrics import roc_curve, roc_auc_score, precision_score, recall_score, accuracy_score, confusion_matrix, auc
import matplotlib.pyplot as plt
from rdsutils.woe import WOE_Transform, get_monotone_dir 
from rdsutils.feature_selection import mrmr
from rdsutils.metrics import get_pred_reports
from rdsutils.plot import plot_auc_curve_mult, plot_pr_curve_mult

warnings.simplefilter(action='ignore')
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 500)

sys.path.insert(1, "./")
from utility.performance_eval_plot import score_gain, plot_efficient_frontier, plot_percentile_bad_rate
import utility.performance_eval_v3 as p_eval
from utility  import data_summary, woe, data_eda, psi

# %load_ext autoreload
# %autoreload 2

print(lgb.__version__)
# Out:
# 3.2.1

# %% [markdown]
# ### read data

# %%
df = pd.read_parquet('./artifact/df_gen4_score_oot_refit.parquet')

# %%
list(df)
# Out:
# ['id',
#  'applicant_type',
#  'date_start',
#  'seg',
#  'ri_source',
#  'target_v2',
#  'weight_eval',
#  'gen4_prescreen_score',
#  'gen4_prescreen_prob',
#  'period',
#  'gen4_underwriting_prob',
#  'gen4_underwriting_score',
#  'gen4_underwriting_prob_29',
#  'gen4_underwriting_score_29',
#  'gen4_underwriting_prob_30',
#  'gen4_underwriting_score_30',
#  'gen3_score',
#  'fico_adj',
#  'applicant_vantage_score',
#  'funds_use_encode_v2',
#  'income_update']

# %%
df["pred_fico"] = -df["fico_adj"]  # reverse dir of fico score
df["pred_gen3"] = -df["gen3_score"]  # reverse dir of gen3 score

# %%
df[['ri_source']].value_counts()
# Out:
# ri_source
# others       968346
# proxy        111313
# booked        71066
# dtype: int64

# %% [markdown]
# ### overall

# %%
pred_cols = ['pred_fico',
             'pred_gen3',
             'gen4_prescreen_prob',
             'gen4_underwriting_prob',
             'gen4_underwriting_prob_29',
             'gen4_underwriting_prob_30']


print(f"--------TTD --------")
test_df_ = df.copy()
print(test_df_.shape)

perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                            sample_weight_col="weight_eval").sort_values("ks")
perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
display(perf.round(4))


print(f"--------booked --------")
test_df_ = df[(df.ri_source=='booked')].copy()
print(test_df_.shape)

perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                            sample_weight_col="weight_eval").sort_values("ks")
perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
display(perf.round(4))
# Out:
# --------TTD --------
# (1150725, 23)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7252  0.3237  32.89  0.8750
# pred_gen3                  0.7546  0.3487  37.59  1.0000
# gen4_prescreen_prob        0.7664  0.3647  39.36  1.0471
# gen4_underwriting_prob_30  0.7727  0.3698  40.50  1.0774
# gen4_underwriting_prob_29  0.7725  0.3696  40.53  1.0782
# gen4_underwriting_prob     0.7727  0.3697  40.54  1.0785
# --------booked --------
# (71066, 23)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.6161  0.0738  16.90  0.5656
# pred_gen3                  0.7023  0.1148  29.88  1.0000
# gen4_prescreen_prob        0.7295  0.1263  33.25  1.1128
# gen4_underwriting_prob_29  0.7366  0.1341  34.43  1.1523
# gen4_underwriting_prob_30  0.7368  0.1343  34.53  1.1556
# gen4_underwriting_prob     0.7367  0.1349  34.68  1.1606

# %% [markdown]
# ### by RI source: funded, proxy, others

# %%
pred_cols = ['pred_fico',
             'pred_gen3',
             'gen4_prescreen_prob',
             'gen4_underwriting_prob',
             'gen4_underwriting_prob_29',
             'gen4_underwriting_prob_30']

for p in ['proxy', 'others']:
    print(f"--------OOT - {p} --------")
    test_df_ = df[df.ri_source ==p].copy()
    print(test_df_.shape)

    perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                                sample_weight_col="weight_eval").sort_values("ks")
    perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
    display(perf.round(4))
# Out:
# --------OOT - proxy --------
# (111313, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.6418  0.1620  20.49  0.7222
# pred_gen3                  0.6950  0.1928  28.37  1.0000
# gen4_prescreen_prob        0.7113  0.2068  30.49  1.0747
# gen4_underwriting_prob_29  0.7193  0.2154  32.16  1.1336
# gen4_underwriting_prob_30  0.7200  0.2164  32.41  1.1424
# gen4_underwriting_prob     0.7192  0.2157  32.46  1.1442
# --------OOT - others --------
# (968346, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7170  0.3468  31.73  0.8789
# pred_gen3                  0.7446  0.3714  36.10  1.0000
# gen4_prescreen_prob        0.7566  0.3879  37.96  1.0515
# gen4_underwriting_prob     0.7627  0.3924  39.06  1.0820
# gen4_underwriting_prob_29  0.7626  0.3923  39.09  1.0828
# gen4_underwriting_prob_30  0.7627  0.3924  39.10  1.0831

# %% [markdown]
# ### by period (OOT1 and OOT2)

# %%
for p in ['oot18q1', 'oot19q2']:
    print(f"--------TTD - period oot - {p} --------")
    test_df_ = df[df.period ==p].copy()
    print(test_df_.shape)

    perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                                sample_weight_col="weight_eval").sort_values("ks")
    perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
    display(perf.round(4))


for p in ['oot18q1', 'oot19q2']:
    print(f"--------booked - period oot - {p} --------")
    test_df_ = df[(df.ri_source=='booked') & (df.period ==p)].copy()
    print(test_df_.shape)

    perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                                sample_weight_col="weight_eval").sort_values("ks")
    perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
    display(perf.round(4))
# Out:
# --------TTD - period oot - oot18q1 --------
# (567316, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7129  0.3122  30.93  0.8613
# pred_gen3                  0.7430  0.3368  35.91  1.0000
# gen4_prescreen_prob        0.7561  0.3544  37.76  1.0515
# gen4_underwriting_prob_29  0.7629  0.3615  39.00  1.0860
# gen4_underwriting_prob_30  0.7631  0.3617  39.01  1.0863
# gen4_underwriting_prob     0.7630  0.3617  39.04  1.0872
# --------TTD - period oot - oot19q2 --------
# (583409, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7380  0.3401  35.05  0.8887
# pred_gen3                  0.7668  0.3622  39.44  1.0000
# gen4_prescreen_prob        0.7772  0.3771  41.06  1.0411
# gen4_underwriting_prob_30  0.7826  0.3798  42.13  1.0682
# gen4_underwriting_prob     0.7826  0.3798  42.17  1.0692
# gen4_underwriting_prob_29  0.7825  0.3796  42.19  1.0697
# --------booked - period oot - oot18q1 --------
# (38086, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.6257  0.0830  18.55  0.6072
# pred_gen3                  0.7051  0.1257  30.55  1.0000
# gen4_prescreen_prob        0.7277  0.1360  32.81  1.0740
# gen4_underwriting_prob_29  0.7342  0.1439  34.11  1.1165
# gen4_underwriting_prob     0.7341  0.1444  34.31  1.1231
# gen4_underwriting_prob_30  0.7341  0.1440  34.48  1.1286
# --------booked - period oot - oot19q2 --------
# (32980, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.5904  0.0583  13.57  0.4771
# pred_gen3                  0.6909  0.0966  28.44  1.0000
# gen4_prescreen_prob        0.7257  0.1103  32.89  1.1565
# gen4_underwriting_prob_30  0.7346  0.1184  34.22  1.2032
# gen4_underwriting_prob_29  0.7342  0.1179  34.55  1.2148
# gen4_underwriting_prob     0.7343  0.1192  34.98  1.2300

# %% [markdown]
# ### by segment (Member/non-Member)

# %%
pred_cols = ['pred_fico',
             'pred_gen3',
             'gen4_underwriting_prob',
            'gen4_underwriting_prob_29']


for p in ['member', 'non_member']:
    print(f"--------TTD - seg - {p} --------")
    test_df_ = df[df.seg ==p].copy()
    print(test_df_.shape)

    perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                                sample_weight_col="weight_eval").sort_values("ks")
    perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
    display(perf.round(4))


for p in ['member', 'non_member']:
    print(f"--------booked - seg - {p} --------")
    test_df_ = df[(df.ri_source=='booked') & (df.seg ==p)].copy()
    print(test_df_.shape)

    perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                                sample_weight_col="weight_eval").sort_values("ks")
    perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
    display(perf.round(4))
# Out:
# --------TTD - seg - member --------
# (99951, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.6815  0.1381  26.29  0.7676
# pred_gen3                  0.7332  0.1716  34.25  1.0000
# gen4_underwriting_prob     0.7688  0.2078  40.06  1.1696
# gen4_underwriting_prob_29  0.7688  0.2078  40.06  1.1696
# --------TTD - seg - non_member --------
# (1050774, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7203  0.3303  32.24  0.8751
# pred_gen3                  0.7498  0.3551  36.84  1.0000
# gen4_underwriting_prob_29  0.7669  0.3755  39.65  1.0763
# gen4_underwriting_prob     0.7670  0.3757  39.71  1.0779
# --------booked - seg - member --------
# (15799, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.6299  0.0627  19.75  0.5720
# pred_gen3                  0.7205  0.1044  34.53  1.0000
# gen4_underwriting_prob     0.7536  0.1231  37.32  1.0808
# gen4_underwriting_prob_29  0.7536  0.1231  37.32  1.0808
# --------booked - seg - non_member --------
# (55267, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.6089  0.0762  15.69  0.5403
# pred_gen3                  0.6987  0.1187  29.04  1.0000
# gen4_underwriting_prob_29  0.7304  0.1389  33.77  1.1629
# gen4_underwriting_prob     0.7304  0.1400  33.81  1.1643

# %% [markdown]
# ### by FICO Band

# %%
df['fico_bin'] = 'other'
df.loc[df.fico_adj>=720, 'fico_bin'] = 'super_prime'
df.loc[(df.fico_adj<720) & (df.fico_adj>=660), 'fico_bin'] = 'prime'
df.loc[(df.fico_adj<660) & (df.fico_adj>=620), 'fico_bin'] = 'near_prime'
df.loc[(df.fico_adj<620), 'fico_bin'] = 'sub_prime'

# %%
pred_cols = ['pred_fico',
             'pred_gen3',
             'gen4_prescreen_prob',
             'gen4_underwriting_prob',
             'gen4_underwriting_prob_29',
             'gen4_underwriting_prob_30']

for p in ['super_prime', 'prime','near_prime','sub_prime']:
    print(f"--------TTD - oot - {p} --------")
    test_df_ = df[df.fico_bin ==p].copy()
    print(test_df_.shape)

    perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                                sample_weight_col="weight_eval").sort_values("ks")
    perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
    display(perf.round(4))
# Out:
# --------TTD - oot - super_prime --------
# (390219, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.6004  0.0775  15.05  0.5054
# pred_gen3                  0.7028  0.1391  29.78  1.0000
# gen4_prescreen_prob        0.7316  0.1549  34.16  1.1471
# gen4_underwriting_prob_29  0.7404  0.1626  35.38  1.1880
# gen4_underwriting_prob_30  0.7408  0.1628  35.44  1.1901
# gen4_underwriting_prob     0.7407  0.1628  35.51  1.1924
# --------TTD - oot - prime --------
# (383489, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.5585  0.1488   8.94  0.4304
# pred_gen3                  0.6457  0.2113  20.77  1.0000
# gen4_prescreen_prob        0.6726  0.2291  24.76  1.1921
# gen4_underwriting_prob_29  0.6866  0.2405  27.08  1.3038
# gen4_underwriting_prob_30  0.6869  0.2408  27.11  1.3052
# gen4_underwriting_prob     0.6873  0.2415  27.17  1.3081
# --------TTD - oot - near_prime --------
# (154742, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.5361  0.2206   5.67  0.3196
# pred_gen3                  0.6243  0.2934  17.74  1.0000
# gen4_prescreen_prob        0.6468  0.3138  21.21  1.1956
# gen4_underwriting_prob_30  0.6603  0.3242  23.27  1.3117
# gen4_underwriting_prob     0.6603  0.3250  23.31  1.3140
# gen4_underwriting_prob_29  0.6595  0.3236  23.32  1.3145
# --------TTD - oot - sub_prime --------
# (222275, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.5985  0.4319  14.73  0.7945
# pred_gen3                  0.6250  0.4517  18.54  1.0000
# gen4_prescreen_prob        0.6450  0.4725  21.57  1.1634
# gen4_underwriting_prob_30  0.6496  0.4748  22.18  1.1963
# gen4_underwriting_prob_29  0.6496  0.4747  22.22  1.1985
# gen4_underwriting_prob     0.6493  0.4744  22.25  1.2001

# %% [markdown]
# ### by Loan Purpose
# - 1: CC pay off
# - 2: Debt Consolidation
# - 3: Home Improvement
# - 4: Major Purchase
# - 5: Others

# %%
for p in [1,2,3,4,5]:
    print(f"--------TTD - oot - {p} --------")
    test_df_ = df[df.funds_use_encode_v2 ==p].copy()
    print(test_df_.shape)

    perf = get_pred_reports(test_df_, 'target_v2', pred_cols, 
                                sample_weight_col="weight_eval").sort_values("ks")
    perf["ks_chg"] = perf["ks"] / perf.loc["pred_gen3", "ks"]
    display(perf.round(4))
# Out:
# --------TTD - oot - 1 --------
# (554645, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7067  0.2605  29.80  0.8696
# pred_gen3                  0.7348  0.2854  34.27  1.0000
# gen4_prescreen_prob        0.7494  0.3010  36.48  1.0645
# gen4_underwriting_prob_30  0.7578  0.3088  37.81  1.1033
# gen4_underwriting_prob_29  0.7577  0.3087  37.83  1.1039
# gen4_underwriting_prob     0.7580  0.3090  37.85  1.1045
# --------TTD - oot - 2 --------
# (270962, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7032  0.2999  29.42  0.8694
# pred_gen3                  0.7315  0.3258  33.84  1.0000
# gen4_prescreen_prob        0.7449  0.3405  35.91  1.0612
# gen4_underwriting_prob_30  0.7509  0.3451  37.00  1.0934
# gen4_underwriting_prob     0.7508  0.3453  37.01  1.0937
# gen4_underwriting_prob_29  0.7507  0.3449  37.07  1.0954
# --------TTD - oot - 3 --------
# (82358, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7651  0.3143  39.18  0.8838
# pred_gen3                  0.7956  0.3442  44.33  1.0000
# gen4_prescreen_prob        0.8045  0.3546  45.72  1.0314
# gen4_underwriting_prob_29  0.8078  0.3587  46.66  1.0526
# gen4_underwriting_prob     0.8078  0.3588  46.76  1.0548
# gen4_underwriting_prob_30  0.8081  0.3592  46.78  1.0553
# --------TTD - oot - 4 --------
# (61745, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7390  0.3625  35.11  0.8891
# pred_gen3                  0.7649  0.3916  39.49  1.0000
# gen4_prescreen_prob        0.7739  0.4039  40.52  1.0261
# gen4_underwriting_prob_30  0.7790  0.4066  41.69  1.0557
# gen4_underwriting_prob     0.7787  0.4060  41.70  1.0560
# gen4_underwriting_prob_29  0.7786  0.4058  41.76  1.0575
# --------TTD - oot - 5 --------
# (181015, 24)
#                               auc      ap     ks  ks_chg
# pred_fico                  0.7373  0.4261  36.25  0.9255
# pred_gen3                  0.7536  0.4425  39.17  1.0000
# gen4_prescreen_prob        0.7630  0.4582  40.06  1.0227
# gen4_underwriting_prob_30  0.7678  0.4614  40.95  1.0454
# gen4_underwriting_prob_29  0.7676  0.4613  40.96  1.0457
# gen4_underwriting_prob     0.7677  0.4612  40.97  1.0460

# %% [markdown]
# ### plot Efficient Frontier, Bad Rate by Percentile, ROC on TTD and Funded

# %%
local_artifact_path = "./artifact/"

# %%
target = 'target_v2'
fig, axs = plt.subplots(1, 2, figsize=(20,8))
df_ = df.copy()
preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['gen4_prescreen_prob'], 'gen4_prescreen'),
    (df_['pred_gen3'], 'gen3_score')
]

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'Efficient Frontier: TTD'

plot_efficient_frontier(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                        lw=2, ax=axs[0]
                        )

title = 'Bad Rate by Percentile: TTD'
plot_percentile_bad_rate(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                         ax=axs[1]
                        )

plt.savefig(os.path.join(local_artifact_path, f"perf-efficient-frontier-br-pct_.png"))


fig, axs = plt.subplots(1, 2, figsize=(20,8))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'ROC curve: TTD'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[0])
axs[0].legend()

df_ = df[(df.ri_source=="booked")]
preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['gen4_prescreen_prob'], 'gen4_prescreen'),
    (df_['pred_gen3'], 'gen3_score')
]
title = 'ROC curve: Funded'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[1])
axs[1].legend()
plt.savefig(os.path.join(local_artifact_path, f"perf-roc-ttd-vs-funded_.png"))
# Out:
#     pct_cum_acct   #accts       min       max  target_num  pct_cum_target  pct_cum_nontarget  actual_rate       KS  cum_bads  cum_acct
# 0       0.044455  28170.5  0.484445  0.940281     14220.5        0.149095           0.025915     0.504801  12.3180  0.010288  0.055248
# 1       0.089497  28542.0  0.385298  0.484444     11721.1        0.271986           0.057163     0.410661  21.4823  0.015358  0.109773
# 2       0.135363  29065.0  0.319165  0.385297      9802.7        0.374762           0.092946     0.337268  28.1816  0.019800  0.163813
# 3       0.181839  29450.5  0.269814  0.319164      8331.3        0.462112           0.132179     0.282892  32.9933  0.024198  0.217248
# 4       0.228988  29878.0  0.231321  0.269812      7317.2        0.538829           0.174090     0.244903  36.4739  0.029132  0.270055
# 5       0.276737  30257.5  0.200327  0.231319      6403.3        0.605965           0.218403     0.211627  38.7562  0.033630  0.322567
# 6       0.324922  30534.0  0.175057  0.200324      5634.9        0.665044           0.264658     0.184545  40.0386  0.038700  0.374361
# 7       0.373780  30960.5  0.153723  0.175057      5038.2        0.717868           0.312813     0.162730  40.5055  0.043778  0.425828
# 8       0.423099  31252.5  0.135604  0.153722      4485.3        0.764894           0.362538     0.143518  40.2356  0.049032  0.476644
# 9       0.472928  31576.0  0.119585  0.135603      4063.6        0.807499           0.413648     0.128693  39.3851  0.054972  0.527072
# 10      0.523356  31955.0  0.105034  0.119584      3550.7        0.844726           0.466414     0.111116  37.8312  0.061340  0.576901
# 11      0.574172  32201.5  0.091800  0.105034      2996.8        0.876146           0.520667     0.093064  35.5479  0.067812  0.626220
# 12      0.625639  32614.0  0.079540  0.091799      2632.3        0.903745           0.576364     0.080711  32.7381  0.074681  0.675078
# 13      0.677433  32820.5  0.068052  0.079538      2306.5        0.927927           0.633049     0.070276  29.4878  0.082001  0.723263
# 14      0.729945  33276.0  0.057108  0.068052      1888.9        0.947731           0.691356     0.056765  25.6375  0.090028  0.771012
# 15      0.782752  33463.0  0.046686  0.057107      1654.0        0.965073           0.750448     0.049428  21.4625  0.098954  0.818161
# 16      0.836187  33861.0  0.036449  0.046685      1275.9        0.978450           0.810980     0.037681  16.7470  0.108840  0.864637
# 0       0.043372  27484.0 -564.0 -431.0     13107.6        0.137427           0.026707     0.476917  11.0720  0.016226  0.053733
# 1       0.088671  28705.5 -584.0 -565.0     11461.7        0.257597           0.058740     0.399286  19.8857  0.020768  0.108189
# 2       0.133781  28585.0 -600.0 -585.0      9738.7        0.359703           0.093751     0.340693  26.5952  0.025653  0.162334
# 3       0.178645  28430.0 -615.0 -601.0      7772.4        0.441192           0.132126     0.273387  30.9066  0.030800  0.217884
# 4       0.225759  29855.0 -629.0 -616.0      6932.3        0.513874           0.174709     0.232199  33.9165  0.035629  0.268902
# 5       0.276066  31879.0 -642.0 -630.0      6502.2        0.582047           0.221852     0.203965  36.0195  0.040801  0.319726
# 6       0.324288  30557.5 -653.0 -643.0      5530.3        0.640029           0.268344     0.180980  37.1685  0.046108  0.374219
# 7       0.373147  30961.0 -663.0 -654.0      5003.0        0.692483           0.316566     0.161590  37.5917  0.051407  0.425576
# 8       0.420615  30079.5 -672.0 -664.0      4283.3        0.737391           0.364487     0.142399  37.2904  0.056944  0.478195
# 9       0.470432  31568.0 -681.0 -673.0      4032.2        0.779667           0.415640     0.127731  36.4027  0.062623  0.529568
# 10      0.521805  32554.5 -690.0 -682.0      3759.8        0.819087           0.469132     0.115492  34.9955  0.068222  0.579385
# 11      0.574424  33343.5 -699.0 -691.0      3391.9        0.854649           0.524772     0.101726  32.9877  0.073839  0.626853
# 12      0.625781  32544.5 -708.0 -700.0      2929.6        0.885364           0.579787     0.090018  30.5577  0.080184  0.675712
# 13      0.680274  34531.0 -718.0 -709.0      2667.3        0.913330           0.638980     0.077244  27.4350  0.086898  0.723934
# 14      0.731098  32206.5 -728.0 -719.0      2195.4        0.936347           0.694731     0.068166  24.1616  0.094504  0.774241
# 15      0.782116  32329.0 -739.0 -729.0      1818.6        0.955415           0.751410     0.056253  20.4005  0.102403  0.821355
# 16      0.837666  35201.5 -753.0 -740.0      1613.6        0.972332           0.813806     0.045839  15.8526  0.111259  0.866219
# 17      0.891811  34310.5 -770.0 -754.0      1215.1        0.985072           0.875287     0.035415  10.9785  0.122615  0.911329
# 18      0.946267  34507.5 -795.0 -771.0       871.3        0.994207           0.937772     0.025250   5.6435  0.135716  0.956628
# 19      1.000000  34050.0 -850.0 -796.0       552.5        1.000000           1.000000     0.016226   0.0000  0.150515  1.000000
# No handles with labels found to put in legend.

# %%
target = 'target_v2'
p = 'oot18q1'
fig, axs = plt.subplots(1, 2, figsize=(20,8))
df_ = df[df.period ==p].copy()
preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['gen4_prescreen_prob'], 'gen4_prescreen'),
    (df_['pred_gen3'], 'gen3_score')
]

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'Efficient Frontier: TTD'

plot_efficient_frontier(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                        lw=2, ax=axs[0]
                        )

title = 'Bad Rate by Percentile: TTD'
plot_percentile_bad_rate(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                         ax=axs[1]
                        )

plt.savefig(os.path.join(local_artifact_path, f"perf-efficient-frontier-br-pct_.png"))


fig, axs = plt.subplots(1, 2, figsize=(20,8))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'ROC curve: TTD'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[0])
axs[0].legend()

df_ = df[(df.ri_source=="booked") & (df.period ==p)]
preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['gen4_prescreen_prob'], 'gen4_prescreen'),
    (df_['pred_gen3'], 'gen3_score')
]
title = 'ROC curve: Funded'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[1])
axs[1].legend()
plt.savefig(os.path.join(local_artifact_path, f"perf-roc-ttd-vs-funded_.png"))
# Out:
#     pct_cum_acct   #accts       min       max  target_num  pct_cum_target  pct_cum_nontarget  actual_rate       KS  cum_bads  cum_acct
# 0       0.043843  14308.0  0.489505  0.940281      6980.3        0.137071           0.026606     0.487860  11.0465  0.012466  0.056069
# 1       0.088428  14550.0  0.391543  0.489498      5923.7        0.253394           0.057926     0.407127  19.5468  0.018277  0.111220
# 2       0.133794  14805.0  0.325055  0.391530      5150.8        0.354539           0.092979     0.347909  26.1560  0.022942  0.165757
# 3       0.179957  15065.0  0.275374  0.325046      4424.4        0.441420           0.131613     0.293687  30.9807  0.028150  0.219479
# 4       0.226858  15306.0  0.236959  0.275366      3923.4        0.518464           0.172941     0.256331  34.5523  0.033012  0.272610
# 5       0.274286  15478.0  0.206470  0.236955      3451.5        0.586240           0.216607     0.222994  36.9633  0.038236  0.325288
# 6       0.322300  15669.0  0.181278  0.206467      3039.8        0.645932           0.262461     0.194001  38.3471  0.043266  0.377478
# 7       0.370862  15848.0  0.160124  0.181276      2765.6        0.700240           0.309961     0.174508  39.0279  0.048469  0.428920
# 8       0.420046  16051.0  0.141918  0.160124      2424.0        0.747839           0.359438     0.151019  38.8401  0.054782  0.479854
# 9       0.469791  16234.0  0.125999  0.141918      2255.7        0.792134           0.410191     0.138949  38.1943  0.061177  0.530209
# 10      0.520146  16433.0  0.111323  0.125998      2006.8        0.831541           0.462569     0.122120  36.8972  0.067848  0.579954
# 11      0.571080  16622.0  0.097788  0.111323      1794.2        0.866774           0.516406     0.107941  35.0368  0.074350  0.629138
# 12      0.622522  16788.0  0.085159  0.097786      1454.6        0.895338           0.572079     0.086645  32.3259  0.081527  0.677700
# 13      0.674712  17032.0  0.073296  0.085156      1270.9        0.920294           0.629305     0.074618  29.0989  0.088968  0.725714
# 14      0.727390  17191.0  0.061951  0.073295      1122.1        0.942329           0.687648     0.065273  25.4681  0.097190  0.773142
# 15      0.780521  17339.0  0.051080  0.061950       920.6        0.960406           0.747260     0.053094  21.3146  0.106292  0.820043
# 0       0.043019  14039.0 -565.0 -431.0      6306.6        0.123843           0.028075     0.449220   9.5768  0.019011  0.055947
# 1       0.087028  14362.0 -584.0 -566.0      5707.9        0.235929           0.059496     0.397431  17.6433  0.024725  0.112111
# 2       0.130292  14119.0 -599.0 -585.0      4925.5        0.332651           0.092876     0.348856  23.9775  0.029965  0.163922
# 3       0.178921  15870.0 -615.0 -600.0      4500.8        0.421033           0.134155     0.283604  28.6878  0.035458  0.220013
# 4       0.224057  14730.0 -628.0 -616.0      3585.6        0.491443           0.174619     0.243422  31.6824  0.040578  0.271375
# 5       0.272086  15674.0 -640.0 -629.0      3345.1        0.557131           0.219383     0.213417  33.7748  0.046332  0.327463
# 6       0.318007  14986.0 -650.0 -641.0      2858.5        0.613263           0.263415     0.190745  34.9848  0.051916  0.377999
# 7       0.368775  16568.0 -660.0 -651.0      2932.6        0.670851           0.312923     0.177004  35.7928  0.057659  0.430094
# 8       0.418217  16135.0 -669.0 -661.0      2509.1        0.720122           0.362396     0.155507  35.7726  0.063557  0.483194
# 9       0.464230  15016.0 -677.0 -670.0      2063.7        0.760647           0.409423     0.137433  35.1224  0.069712  0.535770
# 10      0.516806  17158.0 -686.0 -678.0      2166.8        0.803196           0.463853     0.126285  33.9343  0.075068  0.581783
# 11      0.569906  17329.0 -695.0 -687.0      1929.1        0.841078           0.519767     0.111322  32.1311  0.081369  0.631225
# 12      0.622001  17001.0 -704.0 -696.0      1688.7        0.874239           0.575363     0.099329  29.8876  0.088488  0.681993
# 13      0.672537  16492.0 -713.0 -705.0      1453.0        0.902771           0.629967     0.088103  27.2804  0.094939  0.727914
# 14      0.728625  18304.0 -724.0 -714.0      1357.6        0.929431           0.691496     0.074170  23.7935  0.102272  0.775943
# 15      0.779987  16762.0 -735.0 -725.0      1047.8        0.950006           0.748552     0.062510  20.1454  0.110032  0.821079
# 16      0.836078  18305.0 -749.0 -736.0       942.9        0.968522           0.811590     0.051511  15.6932  0.119737  0.869708
# 17      0.887889  16908.0 -765.0 -750.0       698.4        0.982236           0.870444     0.041306  11.1792  0.130594  0.912972
# 18      0.944053  18329.0 -790.0 -766.0       557.5        0.993184           0.934969     0.030416   5.8215  0.142865  0.956981
# 19      1.000000  18258.0 -850.0 -791.0       347.1        1.000000           1.000000     0.019011   0.0000  0.156044  1.000000
# No handles with labels found to put in legend.

# %%
target = 'target_v2'
p = 'oot19q2'
fig, axs = plt.subplots(1, 2, figsize=(20,8))
df_ = df[df.period ==p].copy()
preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['gen4_prescreen_prob'], 'gen4_prescreen'),
    (df_['pred_gen3'], 'gen3_score')
]

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'Efficient Frontier: TTD'

plot_efficient_frontier(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                        lw=2, ax=axs[0]
                        )

title = 'Bad Rate by Percentile: TTD'
plot_percentile_bad_rate(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                         ax=axs[1]
                        )

plt.savefig(os.path.join(local_artifact_path, f"perf-efficient-frontier-br-pct_.png"))


fig, axs = plt.subplots(1, 2, figsize=(20,8))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'ROC curve: TTD'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[0])
axs[0].legend()

df_ = df[(df.ri_source=="booked") & (df.period ==p)]
preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['gen4_prescreen_prob'], 'gen4_prescreen'),
    (df_['pred_gen3'], 'gen3_score')
]
title = 'ROC curve: Funded'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[1])
axs[1].legend()
plt.savefig(os.path.join(local_artifact_path, f"perf-roc-ttd-vs-funded_.png"))
# Out:
#     pct_cum_acct   #accts       min       max  target_num  pct_cum_target  pct_cum_nontarget  actual_rate       KS  cum_bads  cum_acct
# 0       0.044990  13827.0  0.478899  0.864978      7254.2        0.163184           0.025003     0.524640  13.8181  0.008932  0.055406
# 1       0.090386  13952.0  0.379426  0.478883      5751.3        0.292560           0.056198     0.412220  23.6362  0.013091  0.109929
# 2       0.136644  14217.0  0.313276  0.379418      4637.5        0.396880           0.092638     0.326194  30.4242  0.016935  0.163712
# 3       0.183332  14349.0  0.264367  0.313271      3921.3        0.485090           0.132304     0.273280  35.2786  0.021200  0.217035
# 4       0.230591  14524.5  0.225661  0.264367      3327.8        0.559949           0.174896     0.229116  38.5053  0.025564  0.269802
# 5       0.278356  14680.0  0.194094  0.225660      2945.7        0.626213           0.219533     0.200661  40.6680  0.029780  0.321934
# 6       0.326541  14809.0  0.168582  0.194093      2552.9        0.683641           0.266155     0.172388  41.7486  0.034454  0.373629
# 7       0.375517  15052.0  0.147138  0.168581      2336.4        0.736198           0.314525     0.155222  42.1673  0.039328  0.424895
# 8       0.424498  15054.0  0.129128  0.147136      1999.1        0.781168           0.364185     0.132795  41.6983  0.043982  0.475498
# 9       0.474323  15313.0  0.113115  0.129128      1797.1        0.821594           0.415599     0.117358  40.5995  0.049089  0.525677
# 10      0.524502  15422.0  0.098975  0.113115      1503.5        0.855415           0.468544     0.097491  38.6871  0.055000  0.575502
# 11      0.575105  15552.0  0.086114  0.098974      1291.7        0.884472           0.522790     0.083057  36.1682  0.061102  0.624483
# 12      0.626371  15756.0  0.074214  0.086113      1179.3        0.911001           0.578239     0.074848  33.2762  0.067946  0.673459
# 13      0.678066  15888.0  0.063243  0.074214      1009.9        0.933718           0.634835     0.063564  29.8883  0.074920  0.721644
# 14      0.730198  16022.0  0.052837  0.063243       826.7        0.952315           0.692637     0.051598  25.9678  0.082726  0.769409
#     pct_cum_acct   #accts    min    max  target_num  pct_cum_target  pct_cum_nontarget  actual_rate       KS  cum_bads  cum_acct
# 0       0.044062  13542.0 -563.0 -448.0      6832.6        0.153700           0.025522     0.504549  12.8178  0.013149  0.052906
# 1       0.087853  13458.5 -583.0 -564.0      5435.5        0.275972           0.056041     0.403871  21.9931  0.018073  0.106943
# 2       0.134245  14258.0 -600.0 -584.0      4797.7        0.383897           0.092028     0.336492  29.1869  0.021700  0.160541
# 3       0.181535  14534.0 -616.0 -601.0      3814.6        0.469707           0.132804     0.262460  33.6903  0.026268  0.212357
# 4       0.227234  14045.0 -630.0 -617.0      3054.6        0.538421           0.174611     0.217487  36.3810  0.031051  0.267103
# 5       0.274740  14600.5 -643.0 -631.0      2830.5        0.602093           0.219384     0.193863  38.2709  0.036026  0.318268
# 6       0.323684  15042.5 -655.0 -644.0      2521.7        0.658819           0.267013     0.167638  39.1806  0.041071  0.372245
# 7       0.374874  15732.5 -666.0 -656.0      2335.6        0.711358           0.317974     0.148457  39.3384  0.045601  0.423055
# 8       0.425396  15527.5 -676.0 -667.0      2038.4        0.757212           0.369286     0.131277  38.7926  0.050882  0.474920
# 9       0.474403  15061.5 -685.0 -677.0      1728.4        0.796093           0.420004     0.114756  37.6089  0.056114  0.525597
# 10      0.525080  15575.0 -694.0 -686.0      1637.7        0.832933           0.473021     0.105149  35.9912  0.061116  0.574604
# 11      0.576945  15940.0 -703.0 -695.0      1497.7        0.866624           0.527959     0.093959  33.8665  0.066786  0.625126
# 12      0.627755  15616.0 -712.0 -704.0      1230.4        0.894302           0.582682     0.078791  31.1620  0.072968  0.676316
# 13      0.681732  16589.0 -722.0 -713.0      1174.8        0.920729           0.641317     0.070818  27.9412  0.079357  0.725260
# 14      0.732897  15725.0 -732.0 -723.0       974.9        0.942660           0.697425     0.061997  24.5235  0.086396  0.772766
# 15      0.787643  16825.5 -744.0 -733.0       834.6        0.961434           0.758254     0.049603  20.3180  0.093715  0.818465
# 16      0.839459  15925.0 -757.0 -745.0       643.7        0.975914           0.816384     0.040421  15.9530  0.102933  0.865755
# 17      0.893057  16473.0 -774.0 -758.0       476.7        0.986638           0.877233     0.028938  10.9405  0.114812  0.912147
# 18      0.947094  16607.5 -799.0 -775.0       380.2        0.995191           0.938961     0.022893   5.6230  0.128053  0.955938
# 19      1.000000  16260.0 -850.0 -800.0       213.8        1.000000           1.000000     0.013149   0.0000  0.144642  1.000000
# No handles with labels found to put in legend.

# %%
seg = "member"
target = 'target_v2'
fig, axs = plt.subplots(1, 2, figsize=(20,8))
df_ = df[df.seg == seg]
preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['pred_gen3'], 'gen3_score'),
    (df_['pred_fico'], 'fico_adj')
]

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'Efficient Frontier: TTD'

plot_efficient_frontier(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                        lw=2, ax=axs[0]
                        )

title = 'Bad Rate by Percentile: TTD'
plot_percentile_bad_rate(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                         ax=axs[1]
                        )

plt.savefig(os.path.join(local_artifact_path, f"perf-efficient-frontier-br-pct_{seg}.png"))


fig, axs = plt.subplots(1, 2, figsize=(20,8))
df_ = df[df.seg == seg]

preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['pred_gen3'], 'gen3_score'),
    (df_['pred_fico'], 'fico_adj')
]

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'ROC curve: TTD'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[0])
axs[0].legend()

df_ = df[(df.ri_source=="booked")
             & (df.seg==seg)]

preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['pred_gen3'], 'gen3_score'),
    (df_['pred_fico'], 'fico_adj')
]


title = 'ROC curve: Funded'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[1])
axs[1].legend()
plt.savefig(os.path.join(local_artifact_path, f"perf-roc-ttd-vs-funded_{seg}.png"))
# Out:
#     pct_cum_acct  #accts       min       max  target_num  pct_cum_target  pct_cum_nontarget  actual_rate       KS  cum_bads  cum_acct
# 0       0.044419  2728.0  0.244914  0.720141       771.8        0.179999           0.034243     0.282918  14.5756  0.004959  0.049906
# 1       0.090385  2823.0  0.181520  0.244897       545.7        0.307267           0.074107     0.193305  23.3160  0.006063  0.101783
# 2       0.137589  2899.0  0.145455  0.181477       430.7        0.407715           0.117314     0.148568  29.0401  0.008028  0.153537
# 3       0.185069  2916.0  0.120895  0.145442       404.5        0.502052           0.161277     0.138717  34.0775  0.008800  0.205764
# 4       0.233844  2995.5  0.101892  0.120882       356.6        0.585219           0.207470     0.119045  37.7749  0.010525  0.258040
# 5       0.283196  3031.0  0.086626  0.101888       270.7        0.648351           0.255789     0.089310  39.2562  0.012450  0.309696
# 6       0.332476  3026.5  0.074477  0.086625       229.1        0.701782           0.304757     0.075698  39.7025  0.014698  0.361483
# 7       0.382179  3052.5  0.064137  0.074459       216.3        0.752227           0.354404     0.070860  39.7823  0.016844  0.412570
# 8       0.433265  3137.5  0.055236  0.064135       179.7        0.794137           0.406180     0.057275  38.7957  0.019521  0.464341
# 9       0.484328  3136.0  0.047411  0.055236       179.4        0.835976           0.457934     0.057207  37.8042  0.022207  0.515672
# 10      0.535659  3152.5  0.040566  0.047411       146.6        0.870167           0.510552     0.046503  35.9615  0.025361  0.566735
# 11      0.587430  3179.5  0.034344  0.040562       129.9        0.900462           0.563935     0.040855  33.6527  0.028000  0.617821
# 12      0.638517  3137.5  0.029033  0.034343       100.5        0.923900           0.617097     0.032032  30.6803  0.031191  0.667524
# 13      0.690304  3180.5  0.024207  0.029033        89.5        0.944774           0.671204     0.028140  27.3570  0.034251  0.716804
# 19      1.000000  3142.0 -850.0 -813.0        24.4        1.000000           1.000000     0.007766   0.0000  0.069817  1.000000
#     pct_cum_acct  #accts    min    max  target_num  pct_cum_target  pct_cum_nontarget  actual_rate       KS  cum_bads  cum_acct
# 0       0.041350  2539.5 -653.0 -300.0       501.2        0.116890           0.035680     0.197362   8.1210  0.014571  0.054645
# 1       0.087072  2808.0 -671.0 -654.0       380.9        0.205723           0.078166     0.135648  12.7557  0.017316  0.107856
# 2       0.131654  2738.0 -682.0 -672.0       376.5        0.293530           0.119503     0.137509  17.4027  0.022399  0.159635
# 3       0.178792  2895.0 -691.0 -683.0       333.8        0.371379           0.164337     0.115302  20.7042  0.023643  0.212530
# 4       0.222454  2681.5 -698.0 -692.0       284.2        0.437660           0.206301     0.105985  23.1359  0.026004  0.266678
# 5       0.272051  3046.0 -705.0 -699.0       259.0        0.498064           0.255087     0.085030  24.2977  0.028412  0.319897
# 6       0.325116  3259.0 -712.0 -706.0       282.0        0.563832           0.307199     0.086530  25.6633  0.030245  0.375340
# 7       0.370431  2783.0 -718.0 -713.0       214.7        0.613905           0.352156     0.077147  26.1749  0.032997  0.426150
# 8       0.425409  3376.5 -725.0 -719.0       223.7        0.666076           0.407345     0.066252  25.8731  0.035641  0.480697
# 9       0.474819  3034.5 -731.0 -726.0       208.8        0.714772           0.456809     0.068809  25.7963  0.037918  0.525181
# 10      0.519303  2732.0 -737.0 -732.0       170.8        0.754606           0.501642     0.062518  25.2964  0.040574  0.574591
# 11      0.573850  3350.0 -744.0 -738.0       188.6        0.798591           0.556982     0.056299  24.1609  0.042817  0.629569
# 12      0.624660  3120.5 -751.0 -745.0       166.4        0.837399           0.608693     0.053325  22.8706  0.045122  0.674884
# 13      0.680103  3405.0 -759.0 -752.0       139.0        0.869817           0.665863     0.040822  20.3954  0.048140  0.727949
# 14      0.733322  3268.5 -767.0 -760.0       132.3        0.900672           0.720762     0.040477  17.9910  0.050493  0.777546
# 15      0.787470  3325.5 -776.0 -768.0       117.3        0.928028           0.776921     0.035273  15.1107  0.053444  0.821208
# 16      0.840365  3248.5 -786.0 -777.0        89.0        0.948785           0.832227     0.027397  11.6558  0.056802  0.868346
# 17      0.892144  3180.0 -797.0 -787.0       104.9        0.973250           0.886056     0.032987   8.7194  0.060743  0.912928
# 18      0.945355  3268.0 -812.0 -798.0        65.8        0.988596           0.942110     0.020135   4.6486  0.064315  0.958650
# 19      1.000000  3356.0 -850.0 -813.0        48.9        1.000000           1.000000     0.014571   0.0000  0.069817  1.000000
# No handles with labels found to put in legend.

# %%
seg = "non_member"
target = 'target_v2'
fig, axs = plt.subplots(1, 2, figsize=(20,8))
df_ = df[df.seg == seg]
preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['pred_gen3'], 'gen3_score'),
    (df_['pred_fico'], 'fico_adj')
]

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'Efficient Frontier: TTD'

plot_efficient_frontier(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                        lw=2, ax=axs[0]
                        )

title = 'Bad Rate by Percentile: TTD'
plot_percentile_bad_rate(df_[target], preds,
                        sample_weight=df_["weight_eval"],
                        title=title, colors=colors, alpha=1,
                         ax=axs[1]
                        )

plt.savefig(os.path.join(local_artifact_path, f"perf-efficient-frontier-br-pct_{seg}.png"))


fig, axs = plt.subplots(1, 2, figsize=(20,8))
df_ = df[df.seg == seg]

preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['pred_gen3'], 'gen3_score'),
    (df_['pred_fico'], 'fico_adj')
]

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds)]
title = 'ROC curve: TTD'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[0])
axs[0].legend()

df_ = df[(df.ri_source=="booked")
             & (df.seg==seg)]

preds = [
    (df_['gen4_underwriting_prob'], 'gen4_underwriting'),
    (df_['pred_gen3'], 'gen3_score'),
    (df_['pred_fico'], 'fico_adj')
]


title = 'ROC curve: Funded'
plot_auc_curve_mult(df_[target], preds,
                    sample_weight=df_["weight_eval"],
                    title=title, colors=colors,
                    fill_area=False,
                    lw=2,
                    alpha=0.8,
                    ax=axs[1])
axs[1].legend()
plt.savefig(os.path.join(local_artifact_path, f"perf-roc-ttd-vs-funded_{seg}.png"))
# Out:
#     pct_cum_acct   #accts       min       max  target_num  pct_cum_target  pct_cum_nontarget  actual_rate       KS  cum_bads  cum_acct
# 0       0.044927  25710.0  0.492889  0.940281     13100.9        0.143822           0.026205     0.509564  11.7617  0.012328  0.054701
# 1       0.090332  25984.0  0.398631  0.492886     10977.9        0.264338           0.057391     0.422487  20.6947  0.018191  0.108645
# 2       0.136506  26424.0  0.332186  0.398628      9219.0        0.365545           0.093147     0.348887  27.2398  0.022796  0.162392
# 3       0.183222  26734.0  0.282786  0.332185      7923.7        0.452532           0.132239     0.296390  32.0293  0.027851  0.215528
# 4       0.230552  27085.5  0.243742  0.282782      6952.7        0.528859           0.174080     0.256695  35.4779  0.032822  0.268189
# 5       0.278481  27428.5  0.211821  0.243739      6130.9        0.596164           0.218341     0.223523  37.7823  0.037946  0.320461
# 6       0.326869  27690.5  0.185613  0.211818      5466.6        0.656177           0.264528     0.197418  39.1649  0.043283  0.372475
# 7       0.375746  27971.0  0.163579  0.185612      4865.1        0.709586           0.312547     0.173934  39.7039  0.048501  0.423622
# 8       0.425192  28296.5  0.144623  0.163579      4313.9        0.756945           0.362389     0.152453  39.4556  0.054419  0.474420
# 9       0.475092  28556.0  0.128188  0.144623      3895.7        0.799712           0.413639     0.136423  38.6073  0.060736  0.524908
# 10      0.525580  28892.5  0.113210  0.128187      3469.9        0.837805           0.466473     0.120097  37.1332  0.067307  0.574808
# 11      0.576378  29070.0  0.099577  0.113209      3016.7        0.870922           0.520618     0.103774  35.0304  0.074051  0.624254
# Out:
# gen4_prescreen_prob AUC:  0.75609  KS:  37.7
#
# Gains Table--Model:
#    pct_cum_acct   #accts     min     max  target_num pct_cum_target pct_cum_nontarget actual_rate    KS
# 0          4.4%  14295.0  0.4931  0.9123      6864.2          13.5%              2.7%       48.0%  10.8
# 1          8.8%  14552.0  0.3824  0.4931      5861.4          25.0%              5.9%       40.3%  19.1
# 2         13.4%  14837.0  0.3127  0.3824      5009.1          34.8%              9.4%       33.8%  25.4
# 3         18.0%  15105.0  0.2643  0.3127      4410.5          43.5%             13.3%       29.2%  30.2
# 4         22.7%  15349.0  0.2271  0.2643      3859.5          51.1%             17.5%       25.1%  33.6
# 5         27.5%  15546.0  0.1983  0.2271      3385.7          57.7%             21.9%       21.8%  35.8
# 6         32.3%  15779.0  0.1750  0.1983      3024.3          63.7%             26.5%       19.2%  37.2
# 7         37.2%  15904.0  0.1553  0.1750      2731.4          69.0%             31.3%       17.2%  37.7
# 8         42.1%  16101.0  0.1386  0.1553      2416.1          73.8%             36.3%       15.0%  37.5
# 9         47.1%  16260.0  0.1238  0.1386      2304.8          78.3%             41.3%       14.2%  37.0
# 10        52.2%  16497.0  0.1104  0.1238      2032.3          82.3%             46.6%       12.3%  35.7
# 11        57.3%  16729.0  0.0982  0.1104      1821.8          85.9%             52.0%       10.9%  33.9
# 12        62.5%  16857.0  0.0867  0.0982      1611.9          89.0%             57.5%        9.6%  31.5
# 13        67.7%  17004.0  0.0757  0.0867      1324.5          91.6%             63.2%        7.8%  28.4
# 14        72.9%  17134.0  0.0652  0.0757      1181.2          93.9%             69.0%        6.9%  24.9
# 15        78.2%  17287.0  0.0547  0.0652      1004.4          95.9%             74.9%        5.8%  21.0
# 16        83.6%  17468.0  0.0443  0.0547       799.9          97.5%             81.0%        4.6%  16.5
# 17        89.0%  17694.0  0.0334  0.0443       598.2          98.7%             87.2%        3.4%  11.5
# 18        94.5%  17853.0  0.0213  0.0334       422.9          99.5%             93.5%        2.4%   6.0
# 19       100.0%  18094.0  0.0008  0.0213       260.5         100.0%            100.0%        1.4%   0.0
# (0.7560902015848823, 37.699999999999996)

# %%
p_eval.model_score_eval(df[df.period!='oot18q1']['target_v2'],
                        df[df.period!='oot18q1']['gen4_prescreen_prob'],
                        Y_weight=df[df.period!='oot18q1']['weight_eval'],decile=20)
# Out:
# gen4_prescreen_prob AUC:  0.77721  KS:  41.0
#
# Gains Table--Model:
#    pct_cum_acct   #accts     min     max  target_num pct_cum_target pct_cum_nontarget actual_rate    KS
# 0          4.5%  13856.0  0.4851  0.8950      7348.5          16.5%              2.5%       53.0%  14.0
# 1          9.1%  14024.5  0.3756  0.4851      5592.4          29.1%              5.7%       39.9%  23.4
# 2         13.7%  14258.5  0.3067  0.3756      4570.6          39.4%              9.4%       32.1%  30.0
# 3         18.4%  14400.0  0.2564  0.3066      3833.8          48.0%             13.4%       26.6%  34.6
# 4         23.2%  14718.5  0.2178  0.2564      3306.0          55.5%             17.7%       22.5%  37.8
# 5         28.0%  14774.0  0.1874  0.2178      2869.6          61.9%             22.3%       19.4%  39.6
# 6         32.9%  14983.5  0.1628  0.1874      2621.7          67.8%             27.0%       17.5%  40.8
# 7         37.8%  15165.0  0.1427  0.1628      2259.8          72.9%             31.9%       14.9%  41.0
# 8         42.8%  15310.5  0.1258  0.1427      1956.9          77.3%             36.9%       12.8%  40.4
# 9         47.8%  15464.0  0.1111  0.1258      1818.6          81.4%             42.1%       11.8%  39.3
# 10        52.9%  15563.5  0.0982  0.1111      1575.9          84.9%             47.5%       10.1%  37.4
# 11        58.0%  15769.0  0.0864  0.0982      1450.3          88.2%             52.9%        9.2%  35.3
# 12        63.2%  15832.5  0.0756  0.0864      1204.4          90.9%             58.5%        7.6%  32.4
# 13        68.3%  15908.0  0.0655  0.0756      1003.9          93.2%             64.1%        6.3%  29.1
# 14        73.6%  16107.0  0.0558  0.0655       892.7          95.2%             69.9%        5.5%  25.3
# 15        78.8%  16149.0  0.0465  0.0558       707.2          96.8%             75.8%        4.4%  21.0
# 16        84.1%  16222.5  0.0371  0.0465       581.0          98.1%             81.8%        3.6%  16.3
# 17        89.4%  16253.5  0.0274  0.0371       420.3          99.0%             87.8%        2.6%  11.2
# 18        94.7%  16316.5  0.0173  0.0274       281.8          99.6%             93.9%        1.7%   5.7
# 19       100.0%  16262.0  0.0007  0.0173       158.3         100.0%            100.0%        1.0%   0.0
# (0.7772128448398186, 41.0)

# %%
p_eval.model_score_eval(df[df.period=='oot18q1']['target_v2'],
                        df[df.period=='oot18q1']['gen4_underwriting_prob_29'],
                        Y_weight=df[df.period=='oot18q1']['weight_eval'],decile=20)
# Out:
# gen4_underwriting_prob_29 AUC:  0.76287  KS:  38.9
#
# Gains Table--Model:
#    pct_cum_acct   #accts     min     max  target_num pct_cum_target pct_cum_nontarget actual_rate    KS
# 0          4.4%  14312.0  0.4886  0.9283      6967.1          13.7%              2.7%       48.7%  11.0
# 1          8.8%  14555.0  0.3906  0.4886      5945.7          25.4%              5.8%       40.8%  19.6
# 2         13.4%  14817.0  0.3247  0.3906      5103.7          35.4%              9.3%       34.4%  26.1
# 3         18.0%  15072.0  0.2755  0.3246      4450.3          44.1%             13.2%       29.5%  30.9
# 4         22.7%  15278.0  0.2371  0.2755      3928.4          51.8%             17.3%       25.7%  34.5
# 5         27.4%  15495.0  0.2065  0.2371      3455.1          58.6%             21.7%       22.3%  36.9
# 6         32.2%  15655.0  0.1815  0.2065      3066.0          64.6%             26.2%       19.6%  38.4
# 7         37.1%  15830.0  0.1605  0.1815      2687.7          69.9%             31.0%       17.0%  38.9
# 8         42.0%  16075.0  0.1422  0.1605      2488.7          74.8%             35.9%       15.5%  38.9
# 9         47.0%  16217.0  0.1261  0.1422      2232.9          79.2%             41.0%       13.8%  38.2
# 10        52.0%  16475.0  0.1115  0.1261      2000.6          83.1%             46.3%       12.1%  36.8
# 11        57.1%  16555.0  0.0978  0.1115      1742.1          86.5%             51.7%       10.5%  34.8
# 12        62.2%  16813.0  0.0852  0.0978      1520.9          89.5%             57.2%        9.0%  32.3
# 13        67.5%  16998.0  0.0734  0.0852      1289.8          92.1%             62.9%        7.6%  29.2
# 14        72.7%  17182.0  0.0622  0.0734      1107.3          94.2%             68.7%        6.4%  25.5
# 15        78.0%  17356.0  0.0512  0.0622       925.3          96.0%             74.7%        5.3%  21.3
# 16        83.4%  17527.0  0.0406  0.0512       776.3          97.6%             80.8%        4.4%  16.8
# 17        88.9%  17815.0  0.0296  0.0406       579.0          98.7%             87.1%        3.3%  11.6
# 18        94.4%  17993.0  0.0182  0.0296       428.7          99.6%             93.4%        2.4%   6.2
# 19       100.0%  18325.0  0.0008  0.0182       228.8         100.0%            100.0%        1.2%   0.0
# (0.7628721778198292, 38.9)

# %%
p_eval.model_score_eval(df[df.period!='oot18q1']['target_v2'],
                        df[df.period!='oot18q1']['gen4_underwriting_prob_29'],
                        Y_weight=df[df.period!='oot18q1']['weight_eval'],decile=20)
# Out:
# gen4_underwriting_prob_29 AUC:  0.78254  KS:  42.2
#
# Gains Table--Model:
#    pct_cum_acct   #accts     min     max  target_num pct_cum_target pct_cum_nontarget actual_rate    KS
# 0          4.5%  13837.5  0.4781  0.8792      7294.0          16.4%              2.5%       52.7%  13.9
# 1          9.0%  13955.5  0.3790  0.4781      5697.1          29.2%              5.6%       40.8%  23.6
# 2         13.7%  14186.0  0.3136  0.3790      4617.7          39.6%              9.3%       32.6%  30.3
# 3         18.3%  14360.5  0.2649  0.3135      3918.9          48.4%             13.2%       27.3%  35.2
# 4         23.1%  14534.0  0.2261  0.2649      3378.4          56.0%             17.5%       23.2%  38.5
# 5         27.9%  14729.5  0.1946  0.2261      2972.5          62.7%             22.0%       20.2%  40.7
# 6         32.7%  14759.5  0.1692  0.1946      2519.9          68.4%             26.6%       17.1%  41.8
# 7         37.5%  15021.5  0.1475  0.1692      2328.7          73.6%             31.4%       15.5%  42.2
# 8         42.4%  15052.0  0.1297  0.1475      2010.7          78.1%             36.4%       13.4%  41.7
# 9         47.4%  15290.0  0.1135  0.1297      1770.1          82.1%             41.5%       11.6%  40.6
# 10        52.4%  15434.5  0.0992  0.1135      1508.3          85.5%             46.8%        9.8%  38.7
# 11        57.5%  15603.0  0.0862  0.0992      1285.4          88.4%             52.3%        8.2%  36.1
# 12        62.6%  15694.0  0.0744  0.0862      1178.9          91.1%             57.8%        7.5%  33.3
# 13        67.8%  15890.5  0.0633  0.0744      1017.4          93.4%             63.5%        6.4%  29.9
# 14        73.0%  16079.5  0.0529  0.0633       830.0          95.2%             69.3%        5.2%  25.9
# 15        78.3%  16141.5  0.0428  0.0529       704.4          96.8%             75.1%        4.4%  21.7
# 16        83.6%  16401.5  0.0333  0.0428       573.2          98.1%             81.2%        3.5%  16.9
# 17        89.0%  16565.0  0.0237  0.0333       416.5          99.0%             87.3%        2.5%  11.7
# 18        94.5%  16786.5  0.0140  0.0237       278.8          99.7%             93.6%        1.7%   6.1
# 19       100.0%  17016.0  0.0005  0.0140       153.2         100.0%            100.0%        0.9%   0.0
# (0.7825408422314439, 42.199999999999996)
