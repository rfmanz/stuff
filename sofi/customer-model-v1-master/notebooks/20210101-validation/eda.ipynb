# %% [markdown]
# ### We managed to get the data to run. Let's see if the pipeline works

# %%
import sys
sys.path.insert(1, "../../")
from src.combine import combine_data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('seaborn-poster')

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_feather("../../data/combined_all_features/combined_1609721645.feather")

# %%
df.shape
# Out:
# (4114619, 106)

# %%
fig = plt.figure(figsize=(12,8))
df.sample_date.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
from rdsutils.aws import pandas_df_to_s3

# %%
bucket = "sofi-data-science"
path = "jxu/monitoring/customer-risk-v1/2021-01/dev-data.parquet"
pandas_df_to_s3(df, bucket, path, file_format="parquet")
