# %% [markdown]
# # Instalación de librerías necesarias !!

# %%
#from bayes_opt import BayesianOptimization

# %%
# %%time
#!pip install --upgrade pip
#!pip install bayesian-optimization
#!pip install lightgbm
#!pip install dfply
###############################################################################
# Esenciales
from dfply import *
import pandas as pd ## Manejo de dataframes o set de datos
import numpy as np ## Todo lo referente a trabajar con vectores y matrices
###############################################################################
# Pre Procesamiento
from subprocess import check_output
from sklearn.base import TransformerMixin
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import LabelEncoder ## Kit de funciones para data analytics
###############################################################################
# Métricas y Modelamiento optimizado
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import f1_score, confusion_matrix, roc_auc_score, roc_curve, auc
from bayes_opt import BayesianOptimization
###############################################################################
# Visualización
import matplotlib.pyplot as plt2 ## Todo lo referente a gráficas y demás.
import matplotlib as plt
import seaborn as sns # Se basa en Matplotlib y la complementa en el tema de gráficos y demás
###############################################################################
# Validar particion
from scipy import stats ## Herramientas y algoritmos matemáticos para python
from scipy.stats import ks_2samp, mode ## Herramientas y algoritmos matemáticos para python
###############################################################################
# Modelos
import lightgbm as lgb
import xgboost as xgb
import warnings
warnings.filterwarnings("ignore")4

# %%
# %%time

# Librerias Necesarias
#Importar las librerías necesarias en Python.
import numpy as np
import os, boto3
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder ## Kit de funciones para data analytics
import pandas as pd ## Manejo de dataframes o set de datos
import warnings
import matplotlib.pyplot as plt2 ## Todo lo referente a gráficas y demás.
import matplotlib as plt
import numpy as np ## Todo lo referente a trabajar con vectores y matrices
from scipy import stats ## Herramientas y algoritmos matemáticos para python
import seaborn as sns # Se basa en Matplotlib y la complementa en el tema de graficos y demás.

import requests, io, sys
if sys.version_info[0] < 3:
    from StringIO import StringIO #Python 2.x
else:
    from io import StringIO #Python 3.x
    
pd.options.display.max_rows = 4000
warnings.filterwarnings("ignore")
# %matplotlib inline
# Out:
# CPU times: user 759 µs, sys: 3 µs, total: 762 µs
# Wall time: 770 µs

# %% [markdown]
# # Lectura de informacion desde S3

# %%
# DataSet01
client = boto3.client('s3')
bucket_name = 'sftp-analytics-stg-transferbucket-a3e4afdvn23'
object_key = 'data/output/VariablesImportantesFuentes/2019/11/20/90a099d5-26f0-4236-a9e0-905f9704b118.csv'
csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
Body = csv_obj['Body']
#csv_string = Body.read().decode('utf-8')

csv_string = Body.read().decode('latin-1')
df_churn01 = pd.read_csv(StringIO(csv_string),sep=",")

del csv_obj
del csv_string
del object_key
del bucket_name
del Body
del client

# %%
# DataSet01
client = boto3.client('s3')
bucket_name = 'sftp-analytics-stg-transferbucket-a3e4afdvn23'
object_key = 'data/output/VariablesImportantesFuentes/2019/11/20/7fdd9ab1-f8d4-46d1-9411-dddfb06dcdf0.csv'
csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
Body = csv_obj['Body']
#csv_string = Body.read().decode('utf-8')

csv_string = Body.read().decode('latin-1')
df_churn02 = pd.read_csv(StringIO(csv_string),sep=",")

del csv_obj
del csv_string
del object_key
del bucket_name
del Body
del client

# %%
# DataSet01
client = boto3.client('s3')
bucket_name = 'sftp-analytics-stg-transferbucket-a3e4afdvn23'
object_key = 'data/output/VariablesImportantesFuentes/2019/11/20/34afe38c-5a52-426e-adac-a5fe361182a2.csv'
csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
Body = csv_obj['Body']
#csv_string = Body.read().decode('utf-8')

csv_string = Body.read().decode('latin-1')
df_churn03 = pd.read_csv(StringIO(csv_string),sep=",")

del csv_obj
del csv_string
del object_key
del bucket_name
del Body
del client

# %%
# DataSet01
client = boto3.client('s3')
bucket_name = 'sftp-analytics-stg-transferbucket-a3e4afdvn23'
object_key = 'data/output/VariablesImportantesFuentes/2019/11/20/a6ed0946-e6e7-46f2-b512-56b023967f52.csv'
csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
Body = csv_obj['Body']
#csv_string = Body.read().decode('utf-8')

csv_string = Body.read().decode('latin-1')
df_churn04 = pd.read_csv(StringIO(csv_string),sep=",")

del csv_obj
del csv_string
del object_key
del bucket_name
del Body
del client

# %%
# DataSet01
client = boto3.client('s3')
bucket_name = 'sftp-analytics-stg-transferbucket-a3e4afdvn23'
object_key = 'data/output/VariablesImportantesFuentes/2019/11/20/bc81e957-8500-4871-b838-f0126a29ee82.csv'
csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
Body = csv_obj['Body']
#csv_string = Body.read().decode('utf-8')

csv_string = Body.read().decode('latin-1')
df_churn05 = pd.read_csv(StringIO(csv_string),sep=",")

del csv_obj
del csv_string
del object_key
del bucket_name
del Body
del client

# %%
# DataSet01
client = boto3.client('s3')
bucket_name = 'sftp-analytics-stg-transferbucket-a3e4afdvn23'
object_key = 'data/output/VariablesImportantesFuentes/2019/11/20/c824cac5-91e3-493f-a788-9346e5616fbc.csv'
csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
Body = csv_obj['Body']
#csv_string = Body.read().decode('utf-8')

csv_string = Body.read().decode('latin-1')
df_churn06 = pd.read_csv(StringIO(csv_string),sep=",")

del csv_obj
del csv_string
del object_key
del bucket_name
del Body
del client

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: 
        print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
# Reduccion de memoria
df_churn01 = reduce_mem_usage(df_churn01)
df_churn02 = reduce_mem_usage(df_churn02)
df_churn03 = reduce_mem_usage(df_churn03)
df_churn04 = reduce_mem_usage(df_churn04)
df_churn05 = reduce_mem_usage(df_churn05)
df_churn06 = reduce_mem_usage(df_churn06)
# Out:
# Mem. usage decreased to 503.59 Mb (56.8% reduction)
# Mem. usage decreased to 256.21 Mb (57.4% reduction)
# Mem. usage decreased to 887.90 Mb (49.7% reduction)
# Mem. usage decreased to 516.83 Mb (67.5% reduction)
# Mem. usage decreased to 348.97 Mb (55.1% reduction)
# Mem. usage decreased to 322.47 Mb (85.5% reduction)

# %%
# Tablas listas
#df_churn01_r.head(1)  # Fuente Rcc01, acá está el target : acf0caf3-98fd-4ac5-ae6c-6bf36bc1c3f0.csv
#df_churn02_r.head(1) # Fuente Rcc02, acá esta RCC02     :  7a7eff3e-623e-498a-9f05-13b44f11ae05.csv
#df_churn03_r.head(1) # Fuente Cliente                   :  15c60718-538b-40af-ab7f-3482f0e8cc6c.csv
#df_churn04_r.head(1) # Fuente diversas                    :  b4b3f478-ee31-496c-a308-0c4bbcfd497e.csv
#df_churn01.head(1) # Fuente diversas                    :  96db93ea-4158-4326-94e6-4727155dd54b.csv

# %%
df_tot1 = pd.merge(df_churn01,df_churn02, on=['codmes', 'key_value'], how = 'inner')

# %%
df_tot2 = pd.merge(df_tot1,df_churn03, on=['codmes', 'key_value'], how = 'inner')

# %%
df_tot3 = pd.merge(df_tot2,df_churn04, on=['codmes', 'key_value'], how = 'inner')

# %%
df_tot4 = pd.merge(df_tot3,df_churn05, on=['codmes', 'key_value'], how = 'inner')

# %%
df_tot5 = pd.merge(df_tot4,df_churn06, on=['codmes', 'key_value'], how = 'inner')

# %%
# Reduccion de memoria
df_tot5 = reduce_mem_usage(df_tot5)
# Out:
# Mem. usage decreased to 2606.54 Mb (0.0% reduction)

# %%
# Comprobamos el target total
df_tot5.flg_fuga_vol.value_counts()
# Out:
# 0    4583428
# 1      49043
# Name: flg_fuga_vol, dtype: int64

# %%
df_tot5.shape
# Out:
# (4632471, 220)

# %% [markdown]
# # Revisión de Missings

# %%
# Revisión de Valores Nulos:
#train.shape
df_tot5.isnull().sum()
# Out:
# codmes                             0
# key_value                          0
# promsaldototibk3m                  0
# desvsaldototibk_m16                0
# lin_tcribksf03m                    0
# promsaldototibk6m                  0
# cre_lin_tc_rccibk_m07              0
# desvsaldototibk_m13                0
# prom_sow_lintcribksf3m             0
# sow_lintcribksfm01                 0
# lin_tcribksf06m                    0
# prom_salvig_tc_rccibk_06m          0
# ratsaldototibk_m16                 0
# sow_svtcribksfm01                  0
# desv_uso_tc_rccibk_m13             0
# prm_lintcribksf03m                 0
# promsaldototrcc6m                  0
# cre_lin_tc_rccibk_m04              0
# prom_lin_tc_rccsf_06m              0
# desvlintcibksf_m16                 0
# prom_sow_lintcribksf6m             0
# lin_tcrrstsf06m                    0
# cre_lin_tc_rccsf_m07               0
# prm_lintcrrstsf06m                 0
# ratsaldototibk_m13                 0
# ...

# %%
df_tot5 = df_tot5[['codmes',
'promsaldototibk3m',
'desvsaldototibk_m16',
'lin_tcribksf03m',
'promsaldototibk6m',
'cre_lin_tc_rccibk_m07',
'desvsaldototibk_m13',
'prom_sow_lintcribksf3m',
'sow_lintcribksfm01',
'lin_tcribksf06m',
'prom_salvig_tc_rccibk_06m',
'ratsaldototibk_m16',
'sow_svtcribksfm01',
'desv_uso_tc_rccibk_m13',
'prm_lintcribksf03m',
'promsaldototrcc6m',
'cre_lin_tc_rccibk_m04',
'prom_lin_tc_rccsf_06m',
'desvlintcibksf_m16',
'prom_sow_lintcribksf6m',
'lin_tcrrstsf06m',
'cre_lin_tc_rccsf_m07',
'prm_lintcrrstsf06m',
'ratsaldototibk_m13',
'ratsaldototrccsf_m13',
'cre_salvig_tc_rccibk_m02',
'ratsaldototrccsf_m16',
'prom_salvig_pp_rccsf_06m',
'ctd_prod_rccsf_m01',
'cre_saltot_tc_rccsf_m04',
'desvsaldototrcc_m16',
'prm_sldvigibksf12m',
'sow_lnep1tcrallsfm01',
'prm_sldvigrstsf12m',
'sld_ep1tcrallsfm01',
'sld_ep1actallsfm01',
'sld_ep1lntcrallsfm01',
'flg_lintcrsrcf',
'slddpn_tcrsrcf',
'sldtot_tcrsrcf',
'slddpn_tcrripsaga',
'sld_ep1ppeallsfm01',
'flg_sttcrsrcf',
'slddpn_tcrsaga',
'flg_stltcrsrcf',
'cre_sldtotfinprm06',
'cre_sldtotfinprm09',
'cre_sldtotfinprm12',
'rat_sldtotfinprm06',
'rat_sldtotfinprm09',
'rat_sldtotfinprm12',
'prm_sldtotfinpr06m',
'prm_sldtotfinpr12m',
'cre_sldtotfinplam03',
'cre_sldtotfinplam06',
'cre_sldtotfinplam09',
'cre_sldtotfinplam12',
'rat_sldtotfinplam03',
'rat_sldtotfinplam06',
'rat_sldtotfinplam12',
'prm_sldtotfinpla06m',
'prm_sldtotfinpla12m',
'cre_sldtotfintrxm06',
'cre_sldtotfintrxm09',
'cre_sldtotfintrxm12',
'rat_sldtotfintrxm06',
'rat_sldtotfintrxm09',
'rat_sldtotfintrxm12',
'prm_sldtotfintrx06m',
'prm_sldtotfintrx12m',
'cre_sldtotprmprm06',
'cre_sldtotprmprm12',
'rat_sldtotprmprm06',
'rat_sldtotprmprm09',
'rat_sldtotprmprm12',
'prm_sldtotprmpr06m',
'prm_sldtotprmpr12m',
'cre_sldtotprmplam06',
'cre_sldtotprmplam09',
'cre_sldtotprmplam12',
'rat_sldtotprmplam06',
'rat_sldtotprmplam12',
'prm_sldtotprmpla06m',
'prm_sldtotprmpla12m',
'cre_sldtotprmtrxm06',
'cre_sldtotprmtrxm09',
'cre_sldtotprmtrxm12',
'rat_sldtotprmtrxm06',
'rat_sldtotprmtrxm09',
'rat_sldtotprmtrxm12',
'prm_sldtotprmtrx06m',
'prm_sldtotprmtrx12m',
'grupo_frescura',
'nro_camp_carga_m1',
'nro_camp_carga_m2',
'nro_camp_carga_m3',
'nro_camp_carga_m4',
'nro_camp_carga_m5',
'nro_camp_carga_m6',
'total_camp_carga_u6m',
'prom_camp_carga_u6m',
'max_camp_carga_u6m',
'min_camp_carga_u6m',
'frec_camp_carga',
'recencia_camp_carga',
'ctd_camp',
'ctd_proac',
'ctd_cttefeproac',
'ctd_cttefereac',
'ctd_cttefetot',
'pct_arribo',
'rng_cem',
'rng_pst',
'frs_grp',
'sgt_cem',
'flg_notdeseaecs01m',
'flg_notdeseaecs02m',
'flg_notdeseaecs03m',
'lvl_buro',
'ptj_buro',
'flg_hijos',
'flg_ten_veh',
'sexo',
'edad',
'est_cvl',
'region',
'sit_lab',
'ing_brt',
'dsv_salvigprmar06m',
'dsv_salvigfinar06m',
'dsv_salvigprmtcr06m',
'dsv_salvigprmlibdis06m',
'max_svprmlibdis06m',
'prm_svprmlibdis06m',
'prm_svprmecs06m',
'uso_tc_rccibk_m06',
'ctd_ent_pp_rccsf_m01',
'uso_tc_rccibk_m01',
'rat_svppallsfm03',
'rat_svppallsfm06',
'max_salvig_tc_rccsf_06m',
'dsv_svppallsf06m',
'uso_tc_rccsf_m01',
'rat_svppallsfm03m06',
'cre_svppallsfm03m06',
'max_svotrppeallsf06m',
'min_salvig_tc_rccsf_06m',
'dsv_svotrppeallsf06m',
'rat_svotrppeallsfm06',
'rat_svotrppeallsfm03',
'max_salvig_tc_rccibk_06m',
'cre_salvig_pp_rccsf_m06',
'rat_svotrppeallsfm03m06',
'uso_otrtcrallsfm01',
'rat_svppibksfm060',
'flg_den_den_u6m',
'flg_den_den_u12m',
'flg_den_den_rech_u6m',
'flg_den_den_rech_u12m',
'flg_rec_expuse_u6m',
'flg_rec_expuse_u12m',
'flg_rec_expuse_rech_u6m',
'flg_rec_expuse_rech_u12m',
'flg_rec_mon_u6m',
'flg_rec_mon_u12m',
'flg_rec_mon_rech_u6m',
'flg_rec_mon_rech_u12m',
'flg_rec_rec_u6m',
'flg_rec_rec_u12m',
'flg_rec_rec_rech_u6m',
'flg_rec_rec_rech_u12m',
'flg_sol_adq_u6m',
'flg_sol_adq_u12m',
'flg_sol_adq_rech_u6m',
'flg_sol_adq_rech_u12m',
'flg_sol_can_u6m',
'flg_sol_can_u12m',
'flg_sol_can_rech_u6m',
'flg_sol_can_rech_u12m',
'flg_sol_des_u6m',
'flg_sol_des_u12m',
'flg_sol_des_rech_u6m',
'flg_sol_des_rech_u12m',
'flg_sol_deu_u6m',
'flg_sol_deu_u12m',
'flg_sol_deu_rech_u6m',
'flg_sol_deu_rech_u12m',
'flg_sol_expuse_u6m',
'flg_sol_expuse_u12m',
'flg_sol_expuse_rech_u6m',
'flg_sol_expuse_rech_u12m',
'flg_sol_mem_u6m',
'flg_sol_mem_u12m',
'flg_sol_mem_rech_u6m',
'flg_sol_mem_rech_u12m',
'flg_sol_mon_u6m',
'flg_sol_mon_u12m',
'flg_sol_mon_rech_u6m',
'flg_sol_mon_rech_u12m',
'flg_sol_pag_u6m',
'flg_sol_pag_u12m',
'flg_sol_pag_rech_u6m',
'flg_sol_pag_rech_u12m',
'flg_sol_rep_u6m',
'flg_sol_rep_u12m',
'flg_sol_rep_rech_u6m',
'flg_sol_rep_rech_u12m',
'flg_sol_tasa_u6m',
'flg_sol_tasa_u12m',
'flg_sol_tasa_rech_u6m',
'flg_sol_tasa_rech_u12m',
'flg_sol_trasl_u6m',
'flg_sol_trasl_u12m',
'flg_sol_trasl_rech_u6m',
'flg_sol_trasl_rech_u12m','flg_fuga_vol'
]]

# %%
# Preprocesamiento Variables Cualitativas #

# %%
# Trbajo con los missings #
# Estado Civil
df_tot5.est_cvl = df_tot5.est_cvl.fillna('SOLTERO') ## Llenamos los valores del set de datos
df_tot5.loc[df_tot5.est_cvl.isin(['CONVIVIENTE','DIVORCIADO','VIUDO','SEPARADO']), 'est_cvl'] = 'OTROS' # Recodificamos un grupo de variables
df_tot5.est_cvl = df_tot5.est_cvl.replace({'SOLTERO':0,'CASADO':1,'OTROS':2}) # Recodificacion final

# %%
## Region
df_tot5.region = df_tot5.region.fillna('OTROS') ## Llenamos los valores del set de datos
df_tot5.loc[df_tot5.region.isin(['INF. NO DISPONIBLE','OTROS']), 'region'] = 'OTROS' # Recodificamos un grupo de variables
df_tot5.region = df_tot5.region.replace({'LIMA':0,'SUR':1,'NORTE':2,'CENTRO SUR':3,'CENTRO NORTE':4,'OTROS':5}) # Recodificacion final

# %%
# Situacion Laboral
#df_tot4.sit_lab.value_counts()
df_tot5.sit_lab = df_tot5.sit_lab.fillna('INDEPENDIENTE') ## Llenamos los valores del set de datos

# %%
# Preprocesamiento Variables Cuantitativas #

df_tot5.prom_camp_carga_u6m = df_tot5.prom_camp_carga_u6m.fillna(0)
df_tot5.lvl_buro            = df_tot5.lvl_buro.fillna('SSB')
df_tot5.ptj_buro            = df_tot5.ptj_buro.fillna(0)

# Imputacion por Mediana
df_tot5['ing_brt']=df_tot5['ing_brt'].fillna(df_tot5['ing_brt'].median())
df_tot5['edad']=df_tot5['edad'].fillna(df_tot5['edad'].median())

# %%
df_tot5.codmes.value_counts()
# Out:
# 201908    819406
# 201907    803936
# 201906    787585
# 201905    766217
# 201904    735705
# 201903    719622
# Name: codmes, dtype: int64

# %%
print(df_tot5.shape)
# Out:
# (4632471, 216)

# %% [markdown]
# # Partición Muestral : Train - Test - Val

# %%
# Elegimos los datos de train, test y val
train =       df_tot5.loc[(df_tot5['codmes'] == 201904) | (df_tot5['codmes'] == 201905) |
                             (df_tot5['codmes'] == 201906),:]
test =        df_tot5.loc[(df_tot5['codmes'] == 201907),:]
val_201908 =  df_tot5.loc[(df_tot5['codmes'] == 201908),:]
#val_201904 = df_tot2.loc[(df_tot2['tipo_base']=='validacion') & (df_tot2['codmes']==201904),:]

# %%
# Elegimos los datos de train, test y val
train =       df_tot5.loc[(df_tot5['codmes'] == 201906),:]
test =        df_tot5.loc[(df_tot5['codmes'] == 201907),:]
val_201908 =  df_tot5.loc[(df_tot5['codmes'] == 201908),:]
#val_201904 = df_tot2.loc[(df_tot2['tipo_base']=='validacion') & (df_tot2['codmes']==201904),:]

# %%
# Revisión de Valores Nulos:
train.codmes.value_counts()
#train.isnull().sum()
# Out:
# 201906    787585
# Name: codmes, dtype: int64

# %%
X_train.head(1)
# Out:
#    desvsaldototibk_m16  lin_tcribksf03m  promsaldototibk6m  \
# 0                5.072     226299.15625       17166.935547
#
#    cre_lin_tc_rccibk_m07  desvsaldototibk_m13  prom_sow_lintcribksf3m  \
# 0               0.897949                0.029                0.354004
#
#    sow_lintcribksfm01  lin_tcribksf06m  prom_salvig_tc_rccibk_06m  \
# 0            0.351074     348699.15625               20600.322266
#
#    ratsaldototibk_m16  ...  flg_sol_rep_rech_u6m  flg_sol_rep_rech_u12m  \
# 0               6.072  ...                     0                      0
#
#    flg_sol_tasa_u6m  flg_sol_tasa_u12m  flg_sol_tasa_rech_u6m  \
# 0                 0                  0                      0
#
#    flg_sol_tasa_rech_u12m  flg_sol_trasl_u6m  flg_sol_trasl_u12m  \
# 0                       0                  0                   0
#
#    flg_sol_trasl_rech_u6m  flg_sol_trasl_rech_u12m
# 0                       0                        0
#
# [1 rows x 213 columns]

# %% [markdown]
# # Separación Covariables y Target

# %%
# Train
X_train =  train.iloc[:,2:215]
y_train =  train["flg_fuga_vol"]

# %%
X_train = X_train.drop("flg_fuga_vol",axis=1)

# %%
# Test
X_test =  test.iloc[:,2:215]
y_test =  test["flg_fuga_vol"]

# %%
X_test = X_test.drop("flg_fuga_vol",axis=1)

# %%
# Val 201908
X_val201908 =   val_201908.iloc[:,2:215]
y_val201908 =   val_201908["flg_fuga_vol"]

# %%
X_val201908 = X_val201908.drop("flg_fuga_vol",axis=1)

# %% [markdown]
# # Encoding de Variables

# %%
train.grupo_frescura.value_counts()
# Out:
# G5    1431030
# G1     289038
# G4     208081
# G2     189349
# G3     172009
# Name: grupo_frescura, dtype: int64

# %%
# Out:
# 1    1793877
# 0    1544005
# Name: sexo, dtype: int64

# %%
# Data de entrenamiento
#X_train.region=X_train.region.astype('str')
X_train.lvl_buro=X_train.lvl_buro.astype('str')
X_train.sit_lab=X_train.sit_lab.astype('str')
X_train.grupo_frescura=X_train.grupo_frescura.astype('str')


# Data de testing
#X_test.region=X_test.region.astype('str')
X_test.lvl_buro=X_test.lvl_buro.astype('str')
X_test.sit_lab=X_test.sit_lab.astype('str')
X_test.grupo_frescura=X_test.grupo_frescura.astype('str')


# Data de validacion 201903

#X_val201908.region=X_val201908.region.astype('str')
X_val201908.lvl_buro=X_val201908.lvl_buro.astype('str')
X_val201908.sit_lab=X_val201908.sit_lab.astype('str')
X_val201908.grupo_frescura=X_val201908.grupo_frescura.astype('str')

# %%
# A las variables categoricas le hacemos label encoding pues lgbm no lo admite
features_cat = ['sit_lab','lvl_buro','grupo_frescura']

# %%
# Procedemos con el label encoding
for c in features_cat:
    le = preprocessing.LabelEncoder()
    le.fit(X_train[str(c)])
    X_train[str(c)]=le.transform(X_train[str(c)])
    X_test[str(c)]=le.transform(X_test[str(c)])
    X_val201908[str(c)]=le.transform(X_val201908[str(c)])

# %% [markdown]
# # Seleccion de Variables

# %%
X_train2 = X_train[['prm_sldtotprmpr06m',
'prm_sldtotfinpr06m',
'prm_sldtotfintrx06m',
'dsv_salvigprmtcr06m',
'rat_sldtotprmprm09',
'dsv_salvigprmar06m',
'prm_sldtotprmpla06m',
'prm_sldtotprmtrx06m',
'prm_sldtotprmpr12m',
'prm_sldtotfinpla06m',
'desvsaldototibk_m16',
'prm_sldtotprmtrx12m',
'promsaldototibk6m',
'sow_lintcribksfm01',
'desvsaldototibk_m13',
'prm_sldvigibksf12m',
'pct_arribo',
'nro_camp_carga_m1',
'rat_sldtotfinplam03',
'uso_tc_rccibk_m01',
'dsv_salvigfinar06m',
'ratsaldototibk_m13',
'prm_sldtotfinpr12m',
'ratsaldototibk_m16',
'prm_svprmlibdis06m',
'rat_sldtotfinprm09',
'rat_sldtotfinprm06',
'rat_sldtotprmprm06',
'max_camp_carga_u6m',
'max_salvig_tc_rccibk_06m',
'cre_sldtotfinprm06',
'cre_lin_tc_rccibk_m07',
'rat_sldtotprmplam06',
'prom_camp_carga_u6m',
'rat_sldtotprmprm12',
'sld_ep1actallsfm01',
'rat_sldtotfinplam06',
'edad',
'cre_sldtotprmprm06',
'ptj_buro',
'prm_sldtotfintrx12m',
'sld_ep1tcrallsfm01',
'rat_sldtotfinprm12',
'prom_salvig_tc_rccibk_06m',
'total_camp_carga_u6m',
'prm_sldtotprmpla12m',
'ctd_prod_rccsf_m01',
'uso_tc_rccsf_m01',
'promsaldototrcc6m',
'frs_grp',
'prm_sldtotfinpla12m',
'max_svprmlibdis06m',
'cre_lin_tc_rccibk_m04',
'lin_tcribksf03m',
'dsv_salvigprmlibdis06m',
'flg_lintcrsrcf',
'sow_svtcribksfm01',
'lin_tcribksf06m',
'cre_sldtotprmprm12',
'flg_sol_mon_u12m',
'ing_brt',
'rat_sldtotfintrxm06',
'sld_ep1lntcrallsfm01',
'sit_lab',
'rat_svppibksfm060',
'uso_tc_rccibk_m06',
'rng_cem',
'slddpn_tcrsrcf',
'desv_uso_tc_rccibk_m13',
'sgt_cem',
'prom_lin_tc_rccsf_06m',
'sldtot_tcrsrcf',
'flg_sol_can_u12m',
'flg_sol_can_rech_u12m',
'flg_sol_mon_u6m']]

X_test2=X_test[['prm_sldtotprmpr06m',
'prm_sldtotfinpr06m',
'prm_sldtotfintrx06m',
'dsv_salvigprmtcr06m',
'rat_sldtotprmprm09',
'dsv_salvigprmar06m',
'prm_sldtotprmpla06m',
'prm_sldtotprmtrx06m',
'prm_sldtotprmpr12m',
'prm_sldtotfinpla06m',
'desvsaldototibk_m16',
'prm_sldtotprmtrx12m',
'promsaldototibk6m',
'sow_lintcribksfm01',
'desvsaldototibk_m13',
'prm_sldvigibksf12m',
'pct_arribo',
'nro_camp_carga_m1',
'rat_sldtotfinplam03',
'uso_tc_rccibk_m01',
'dsv_salvigfinar06m',
'ratsaldototibk_m13',
'prm_sldtotfinpr12m',
'ratsaldototibk_m16',
'prm_svprmlibdis06m',
'rat_sldtotfinprm09',
'rat_sldtotfinprm06',
'rat_sldtotprmprm06',
'max_camp_carga_u6m',
'max_salvig_tc_rccibk_06m',
'cre_sldtotfinprm06',
'cre_lin_tc_rccibk_m07',
'rat_sldtotprmplam06',
'prom_camp_carga_u6m',
'rat_sldtotprmprm12',
'sld_ep1actallsfm01',
'rat_sldtotfinplam06',
'edad',
'cre_sldtotprmprm06',
'ptj_buro',
'prm_sldtotfintrx12m',
'sld_ep1tcrallsfm01',
'rat_sldtotfinprm12',
'prom_salvig_tc_rccibk_06m',
'total_camp_carga_u6m',
'prm_sldtotprmpla12m',
'ctd_prod_rccsf_m01',
'uso_tc_rccsf_m01',
'promsaldototrcc6m',
'frs_grp',
'prm_sldtotfinpla12m',
'max_svprmlibdis06m',
'cre_lin_tc_rccibk_m04',
'lin_tcribksf03m',
'dsv_salvigprmlibdis06m',
'flg_lintcrsrcf',
'sow_svtcribksfm01',
'lin_tcribksf06m',
'cre_sldtotprmprm12',
'flg_sol_mon_u12m',
'ing_brt',
'rat_sldtotfintrxm06',
'sld_ep1lntcrallsfm01',
'sit_lab',
'rat_svppibksfm060',
'uso_tc_rccibk_m06',
'rng_cem',
'slddpn_tcrsrcf',
'desv_uso_tc_rccibk_m13',
'sgt_cem',
'prom_lin_tc_rccsf_06m',
'sldtot_tcrsrcf',
'flg_sol_can_u12m',
'flg_sol_can_rech_u12m',
'flg_sol_mon_u6m']]

X_val1 = X_val201908[[
'prm_sldtotprmpr06m',
'prm_sldtotfinpr06m',
'prm_sldtotfintrx06m',
'dsv_salvigprmtcr06m',
'rat_sldtotprmprm09',
'dsv_salvigprmar06m',
'prm_sldtotprmpla06m',
'prm_sldtotprmtrx06m',
'prm_sldtotprmpr12m',
'prm_sldtotfinpla06m',
'desvsaldototibk_m16',
'prm_sldtotprmtrx12m',
'promsaldototibk6m',
'sow_lintcribksfm01',
'desvsaldototibk_m13',
'prm_sldvigibksf12m',
'pct_arribo',
'nro_camp_carga_m1',
'rat_sldtotfinplam03',
'uso_tc_rccibk_m01',
'dsv_salvigfinar06m',
'ratsaldototibk_m13',
'prm_sldtotfinpr12m',
'ratsaldototibk_m16',
'prm_svprmlibdis06m',
'rat_sldtotfinprm09',
'rat_sldtotfinprm06',
'rat_sldtotprmprm06',
'max_camp_carga_u6m',
'max_salvig_tc_rccibk_06m',
'cre_sldtotfinprm06',
'cre_lin_tc_rccibk_m07',
'rat_sldtotprmplam06',
'prom_camp_carga_u6m',
'rat_sldtotprmprm12',
'sld_ep1actallsfm01',
'rat_sldtotfinplam06',
'edad',
'cre_sldtotprmprm06',
'ptj_buro',
'prm_sldtotfintrx12m',
'sld_ep1tcrallsfm01',
'rat_sldtotfinprm12',
'prom_salvig_tc_rccibk_06m',
'total_camp_carga_u6m',
'prm_sldtotprmpla12m',
'ctd_prod_rccsf_m01',
'uso_tc_rccsf_m01',
'promsaldototrcc6m',
'frs_grp',
'prm_sldtotfinpla12m',
'max_svprmlibdis06m',
'cre_lin_tc_rccibk_m04',
'lin_tcribksf03m',
'dsv_salvigprmlibdis06m',
'flg_lintcrsrcf',
'sow_svtcribksfm01',
'lin_tcribksf06m',
'cre_sldtotprmprm12',
'flg_sol_mon_u12m',
'ing_brt',
'rat_sldtotfintrxm06',
'sld_ep1lntcrallsfm01',
'sit_lab',
'rat_svppibksfm060',
'uso_tc_rccibk_m06',
'rng_cem',
'slddpn_tcrsrcf',
'desv_uso_tc_rccibk_m13',
'sgt_cem',
'prom_lin_tc_rccsf_06m',
'sldtot_tcrsrcf',
'flg_sol_can_u12m',
'flg_sol_can_rech_u12m',
'flg_sol_mon_u6m']]

# %%
#X_train.flg_fuga_vol.value_counts()

# %% [markdown]
# # MODELAMIENTO DATOS
# Hacemos el modelamiento de los datos

# %%
#X_total = pd.concat([X_train, X_test], axis = 0)
#Y_total = pd.concat([y_train, y_test], axis = 0)

# %%
#print(X_total.shape)
#print(Y_total.shape)
# Out:
# (375930, 240)
# (375930,)

# %%
params = {
        'task':'train', 
        'is_unbalance': False,  # cuando TRUE se balancea y me puede mandar a la mrd el auc
        'max_dept':6,
        'max_bin': 50,  # max cantidad de cortes de una var. numerica
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'min_child_weight': 150,
        'metric': 'logloss',
        'min_data_in_leaf': 250,
        'num_leaves': 30,
        'learning_rate': 0.003,
        'feature_fraction': 0.8,
        'bagging_fraction': 0.8,
        'bagging_freq': 10,
        'min_data_per_group':150 ,
        'verbose': 0,
        'seed ':1234,
}

# %%
dtrain =       lgb.Dataset(pd.DataFrame(X_train2), pd.DataFrame(y_train))
dtest =        lgb.Dataset(pd.DataFrame(X_test2), pd.DataFrame(y_test), reference=dtrain)
dval201908 =   lgb.Dataset(pd.DataFrame(X_val1), pd.DataFrame(y_val201908), reference=dtrain)

# %%
from numba import jit

@jit
def eval_gini(y_true, y_prob):
    y_true = np.asarray(y_true)
    y_true = y_true[np.argsort(y_prob)]
    ntrue  = 0
    gini   = 0
    delta  = 0
    n = len(y_true)
    for i in range(n-1, -1, -1):
        y_i = y_true[i]
        ntrue += y_i
        gini += y_i * delta
        delta += 1 - y_i
    gini = 1 - 2 * gini / (ntrue * (n - ntrue))

    return gini

def gini_lgb(preds, lgb_train):  
    actuals = np.array(lgb_train.get_label())   
    return 'gini', eval_gini(actuals, preds), True

# %%
# %%time

gbm = lgb.train(params,
            dtrain,
            verbose_eval = 100,
            num_boost_round=1000,
            valid_sets=[dtrain,dtest,dval201908],
            early_stopping_rounds=100,
            feval = gini_lgb)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's gini: 0.925363	valid_1's gini: 0.921249	valid_2's gini: 0.927596
# [200]	training's gini: 0.931643	valid_1's gini: 0.927383	valid_2's gini: 0.932948
# [300]	training's gini: 0.934594	valid_1's gini: 0.930793	valid_2's gini: 0.935818
# [400]	training's gini: 0.936783	valid_1's gini: 0.932753	valid_2's gini: 0.937815
# [500]	training's gini: 0.937624	valid_1's gini: 0.933399	valid_2's gini: 0.938409
# [600]	training's gini: 0.938101	valid_1's gini: 0.93388	valid_2's gini: 0.938773
# [700]	training's gini: 0.93855	valid_1's gini: 0.934439	valid_2's gini: 0.939159
# [800]	training's gini: 0.939202	valid_1's gini: 0.935187	valid_2's gini: 0.93973
# [900]	training's gini: 0.939949	valid_1's gini: 0.935879	valid_2's gini: 0.940298
# [1000]	training's gini: 0.940748	valid_1's gini: 0.936708	valid_2's gini: 0.94101
# Did not meet early stopping. Best iteration is:
# ...

# %%
# Modelo XgBoost

# %%
dtrain =  xgb.DMatrix(data=X_train2, label = y_train)
dtest   = xgb.DMatrix(data=X_test2,   label = y_test)
dval_1 = xgb.DMatrix(data=X_val1, label = y_val201903)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-7dbee0f8961c> in <module>()
# ----> 1 dtrain =  xgb.DMatrix(data=X_train2, label = y_train)
#       2 dtest   = xgb.DMatrix(data=X_test2,   label = y_test)
#       3 dval_1 = xgb.DMatrix(data=X_val1, label = y_val201903)
#
# NameError: name 'X_train2' is not defined

# %%
xgb_params = {
    "objective": "reg:logistic",
    "eta": 0.05,
    "max_depth": 5,
    "early_stopping_rounds":  50,
    "gamma": 0.01,
    "eval_metric": "auc",
    "print_every_n": 50
}

num_rounds = 500

watch_list  = [(dtrain,'train'),(dtest,'test'),(dval_1,'val1')]
xgb_fit = xgb.train(xgb_params, dtrain, num_rounds, watch_list)
# Out:
# [0]	train-auc:0.774102	test-auc:0.744878	val1-auc:0.730959
# [1]	train-auc:0.774584	test-auc:0.744957	val1-auc:0.731367
# [2]	train-auc:0.77655	test-auc:0.74551	val1-auc:0.732466
# [3]	train-auc:0.776713	test-auc:0.745779	val1-auc:0.732702
# [4]	train-auc:0.77698	test-auc:0.74582	val1-auc:0.7328
# [5]	train-auc:0.777021	test-auc:0.745806	val1-auc:0.732842
# [6]	train-auc:0.776995	test-auc:0.745837	val1-auc:0.732766
# [7]	train-auc:0.777035	test-auc:0.745818	val1-auc:0.732621
# [8]	train-auc:0.777075	test-auc:0.745864	val1-auc:0.732663
# [9]	train-auc:0.777159	test-auc:0.745784	val1-auc:0.73256
# [10]	train-auc:0.777157	test-auc:0.745737	val1-auc:0.732599
# [11]	train-auc:0.777804	test-auc:0.745729	val1-auc:0.732566
# [12]	train-auc:0.777921	test-auc:0.746063	val1-auc:0.732924
# [13]	train-auc:0.778344	test-auc:0.746123	val1-auc:0.733196
# [14]	train-auc:0.778708	test-auc:0.746328	val1-auc:0.733309
# [15]	train-auc:0.779221	test-auc:0.746539	val1-auc:0.73324
# ...

# %% [markdown]
# # Importancia de Variables

# %%
importancia=gbm.feature_importance(importance_type='gain')

def impxgb(valores,variables):
    dictimp={variables[a]:valores[a] for a in range(0,len(variables)) }
    xgimp=sorted(list(dictimp.items()), key=lambda x: x[1],reverse=True)

    return xgimp

ixg=impxgb(importancia,X_train2.columns)
pd.Series(ixg)
# Out:
# 0           (prm_sldtotprmpr06m, 1539971.5539372866)
# 1           (prm_sldtotfinpr06m, 1147509.5516548927)
# 2          (prm_sldtotfintrx06m, 367508.42090653506)
# 3          (dsv_salvigprmtcr06m, 223894.50710994191)
# 4           (rat_sldtotprmprm09, 195886.15399684594)
# 5          (prm_sldtotprmpla06m, 181486.12592922887)
# 6           (dsv_salvigprmar06m, 180209.77292118967)
# 7          (prm_sldtotprmtrx06m, 144845.15726011666)
# 8           (desvsaldototibk_m16, 141120.3217838197)
# 9          (prm_sldtotfinpla06m, 137130.30224159523)
# 10         (prm_sldtotprmtrx12m, 127288.06691224615)
# 11           (promsaldototibk6m, 121070.29038494093)
# 12          (sow_lintcribksfm01, 110265.64129246585)
# 13          (desvsaldototibk_m13, 99200.29603547184)
# 14           (prm_sldvigibksf12m, 98210.25075301994)
# 15                   (pct_arribo, 86621.61949527264)
# 16          (rat_sldtotfinplam03, 77152.37520717317)
# 17            (nro_camp_carga_m1, 75777.98069795594)
# ...

# %%
#cols = X_train2.columns.tolist()
#cols

# %%
## Deciles

# %%
predict_test_1 = gbm.predict(pd.DataFrame(X_test2), ntree_limit=gbm.best_iteration)
decile_1 = pd.qcut(pd.Series(predict_test_1), 100, labels=False)
df_final_test_1 = test[['codmes','flg_fuga_vol']]
df_final_test_1 = df_final_test_1.reset_index(drop=True)
df_final_test_1["deciles"] = pd.Series(decile_1)

# %%
print(df_final_test_1[['codmes','deciles','flg_fuga_vol']].groupby(['codmes','deciles']).agg(['count','sum','mean']))
# Out:
#                flg_fuga_vol
#                       count     sum      mean
# codmes deciles
# 201907 0               8040     0.0  0.000000
#        1               8039     0.0  0.000000
#        2               8040     0.0  0.000000
#        3               8039     0.0  0.000000
#        4               8039     0.0  0.000000
#        5               8040     1.0  0.000124
#        6               8039     0.0  0.000000
#        7               8039     0.0  0.000000
#        8               8040     1.0  0.000124
#        9               8039     0.0  0.000000
#        10              8039     1.0  0.000124
#        11              8040     1.0  0.000124
#        12              8039     0.0  0.000000
#        13              8039     1.0  0.000124
#        14              8040     1.0  0.000124
#        15              8039     2.0  0.000249
#        16              8039     0.0  0.000000
#        17              8040     0.0  0.000000
# ...

# %%
# Guardamos el Modelo
import pickle
# Save the model from jyputer
filename = 'lgbm_churncliente02.sav'
pickle.dump(gbm, open(filename, 'wb'))

# %% [markdown]
# # Gini Univariado

# %%
cols = X_train.columns.tolist()
a = 1

gini_normalizado_train = []                    
gini_normalizado_test  = []                       
gini_normalizado_val   = []                        
gini_normalizado_val2   = [] 



for feature in cols:
    
    print("--------------------------")
    print("Variable: ", str(feature), "Iteración numero: ", a, "De ", len(cols))
    print("--------------------------")
    
    X_train_f = pd.DataFrame(X_train[str(feature)])
    X_test_f =  pd.DataFrame(X_test[str(feature)])
    X_val_f =   pd.DataFrame(X_val201903[str(feature)])  
    X_val2_f =   pd.DataFrame(X_val201904[str(feature)])  

    y_train = y_train
    y_test = y_test
    y_val = y_val201903
    y_val2 = y_val201904
    #print(Y_train.shape)
   #print(Y_test.shape)
    #print(Y_val_1901.shape)
    #print(Y_val_1902.shape)
    #print(Y_val_1903.shape)
    
    dtrain = lgb.Dataset(pd.DataFrame(X_train_f), pd.DataFrame(y_train))
    dtest  = lgb.Dataset(pd.DataFrame(X_test_f),  pd.DataFrame(y_test), reference=dtrain)
    dvalid = lgb.Dataset(pd.DataFrame(X_val_f),   pd.DataFrame(y_val), reference=dtrain)
    dvalid2 = lgb.Dataset(pd.DataFrame(X_val2_f),   pd.DataFrame(y_val2), reference=dtrain)

    gbm = lgb.train(params,
                    dtrain,
                    verbose_eval = 100,
                    num_boost_round = 2000,
                    valid_sets = [dtrain,dtest,dvalid,dvalid2],
                    early_stopping_rounds = 100,
                    feval = gini_lgb)
    
    gini_normalizado_train.append(gini_lgb(gbm.predict(pd.DataFrame(X_train_f), 
                                                       ntree_limit=gbm.best_iteration),dtrain)[1])
    gini_normalizado_test.append(gini_lgb(gbm.predict(pd.DataFrame(X_test_f), 
                                                      ntree_limit=gbm.best_iteration),dtest)[1])
    gini_normalizado_val.append(gini_lgb(gbm.predict(pd.DataFrame(X_val_f),
                                                         ntree_limit=gbm.best_iteration),dvalid)[1])
    gini_normalizado_val2.append(gini_lgb(gbm.predict(pd.DataFrame(X_val2_f),
                                                         ntree_limit=gbm.best_iteration),dvalid2)[1])

    a = a + 1
# Out:
# --------------------------
# Variable:  ctd_prod_rccsf_m01 Iteración numero:  1 De  265
# --------------------------
# Training until validation scores don't improve for 100 rounds.
# [100]	training's gini: 0.109103	valid_1's gini: 0.114005	valid_2's gini: 0.125118	valid_3's gini: 0.0936115
# Early stopping, best iteration is:
# [1]	training's gini: 0.109103	valid_1's gini: 0.114005	valid_2's gini: 0.125118	valid_3's gini: 0.0936115
# --------------------------
# Variable:  promctdprodrccsf3m Iteración numero:  2 De  265
# --------------------------
# Training until validation scores don't improve for 100 rounds.
# [100]	training's gini: 0.0961895	valid_1's gini: 0.104173	valid_2's gini: 0.1146	valid_3's gini: 0.0833623
# Early stopping, best iteration is:
# [1]	training's gini: 0.0961895	valid_1's gini: 0.104173	valid_2's gini: 0.1146	valid_3's gini: 0.0833623
# --------------------------
# Variable:  promctdprodrccsf6m Iteración numero:  3 De  265
# --------------------------
# ...

# %% [markdown]
# # Rubustez por variables

# %%
# %%time
var_robust = pd.DataFrame({"Variable": cols, "GINI_TRAIN": gini_normalizado_train, "GINI_TEST": gini_normalizado_test,
                          "GINI_VAL": gini_normalizado_val,"GINI_VAL2": gini_normalizado_val2})
# Out:
# CPU times: user 0 ns, sys: 1.42 ms, total: 1.42 ms
# Wall time: 1.19 ms

# %%
# %%time

var_robust
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
#                               Variable  GINI_TRAIN  GINI_TEST  GINI_VAL  \
# 0                   ctd_prod_rccsf_m01    0.109103   0.114005  0.125118
# 1                   promctdprodrccsf3m    0.096190   0.104173  0.114600
# 2                   promctdprodrccsf6m    0.089480   0.097365  0.104151
# 3                  ctd_prod_rccibk_m01    0.074355   0.096145  0.067340
# 4                  promctdprodrccibk3m    0.063929   0.093565  0.053613
# 5                  promctdprodrccibk6m    0.059827   0.079887  0.032961
# 6                cre_lin_tc_rccibk_m02    0.093789   0.115391  0.029872
# 7                cre_lin_tc_rccibk_m04    0.109046   0.111942  0.019065
# 8                cre_lin_tc_rccibk_m07    0.118592   0.129149  0.041521
# 9                 cre_lin_tc_rccsf_m02    0.101770   0.110681  0.024349
# 10                cre_lin_tc_rccsf_m04    0.097634   0.091513  0.019515
# ...

# %%
#gbm.predict(pd.DataFrame(X_val), ntree_limit=gbm.best_iteration)

# %% [markdown]
# ## Guardamos el modelo

# %%
import pickle

# %%
# Save the model from jyputer
filename = 'lgbm_ec7.sav'
pickle.dump(gbm, open(filename, 'wb'))

# %%
# FIN!!

# %%
## Modelamiento con Variables Finales ##
#X_train2.shape #(249644, 64)
X_test2.shape
# Out:
# (126286, 64)

# %%
dtrain =       lgb.Dataset(pd.DataFrame(X_train2), pd.DataFrame(y_train))
dtest =        lgb.Dataset(pd.DataFrame(X_test2), pd.DataFrame(y_test), reference=dtrain)
dval201903 =   lgb.Dataset(pd.DataFrame(X_val1), pd.DataFrame(y_val201903), reference=dtrain)
dval201904 =   lgb.Dataset(pd.DataFrame(X_val2), pd.DataFrame(y_val201904), reference=dtrain)

# %%
params = {
        'task':'train', 
        'is_unbalance': False,  # cuando TRUE se balancea y me puede mandar a la mrd el auc
        'max_dept':6,
        'max_bin': 50,  # max cantidad de cortes de una var. numerica
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'min_child_weight': 150,
        'metric': 'logloss',
        'min_data_in_leaf': 250,
        'num_leaves': 30,
        'learning_rate': 0.003,
        'feature_fraction': 0.8,
        'bagging_fraction': 0.8,
        'bagging_freq': 10,
        'min_data_per_group':150 ,
        'verbose': 0,
        'seed ':1234
}

# %%
gbm = lgb.train(params,
            dtrain,
            verbose_eval = 100,
            num_boost_round=10000,
            valid_sets=[dtrain,dtest,dval201903,dval201904],
            early_stopping_rounds=100,
            feval = gini_lgb)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	training's gini: 0.535457	valid_1's gini: 0.513206	valid_2's gini: 0.474471	valid_3's gini: 0.455908
# [200]	training's gini: 0.542948	valid_1's gini: 0.520176	valid_2's gini: 0.483176	valid_3's gini: 0.461944
# [300]	training's gini: 0.550321	valid_1's gini: 0.526797	valid_2's gini: 0.490617	valid_3's gini: 0.467722
# [400]	training's gini: 0.558013	valid_1's gini: 0.533316	valid_2's gini: 0.49861	valid_3's gini: 0.474943
# [500]	training's gini: 0.564268	valid_1's gini: 0.538668	valid_2's gini: 0.504958	valid_3's gini: 0.480054
# [600]	training's gini: 0.569344	valid_1's gini: 0.542948	valid_2's gini: 0.509598	valid_3's gini: 0.484795
# [700]	training's gini: 0.573651	valid_1's gini: 0.546181	valid_2's gini: 0.51389	valid_3's gini: 0.488964
# [800]	training's gini: 0.577185	valid_1's gini: 0.548842	valid_2's gini: 0.517062	valid_3's gini: 0.491999
# ...

# %%
# Mejores parametros
params = {
        'task':'train', 
        'is_unbalance': False,  # cuando TRUE se balancea y me puede mandar a la mrd el auc
        'max_dept':6,
        'max_bin': 50,  # max cantidad de cortes de una var. numerica
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'min_child_weight': 150,
        'metric': 'logloss',
        'min_data_in_leaf': 250,
        'num_leaves': 30,
        'learning_rate': 0.001,
        'feature_fraction': 0.8,
        'bagging_fraction': 0.8,
        'bagging_freq': 10,
        'min_data_per_group':150 ,
        'verbose': 0,
        'seed ':1234
}
