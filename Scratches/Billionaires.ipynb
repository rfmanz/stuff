# %%
from pyutils import *
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# ...

# %%
bil = pd.read_csv("/home/r/Downloads/Billionaire.csv")

# %%
peek(bil)
# Out:
#                0              0              1                         2
# Name      object     Jeff Bezos      Elon Musk  Bernard Arnault & family
# NetWorth  object         $177 B         $151 B                    $150 B
# Country   object  United States  United States                    France
# Source    object         Amazon  Tesla, SpaceX                      LVMH
# Rank       int64              1              2                         3

# %%
bil
# Out:
#                           Name NetWorth        Country         Source  Rank
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
# [2755 rows x 5 columns]

# %%
bil.shape
# Out:
# (2755, 5)

# %%
from pyutils import eda

# %%
eda.ordered_barplot_h(bil, "Country")

# %%
pd.options.display.max_rows=65 
bil[bil.Country == "Brazil"].sort_values("NetWorth",ascending=False)
# Out:
#                                        Name NetWorth Country  \
# 283        Carlos Alberto Sicupira & family   $8.7 B  Brazil
# 365                          Safra siblings   $7.1 B  Brazil
# 371                       Alexandre Behring     $7 B  Brazil
# 454           Dulce Pugliese de Godoy Bueno     $6 B  Brazil
# 522                    Alceu Elias Feldmann   $5.4 B  Brazil
# 534                    Luiza Helena Trajano   $5.3 B  Brazil
# 628                              Luis Frias   $4.6 B  Brazil
# 638                           Andre Esteves   $4.5 B  Brazil
# 814          Candido Pinheiro Koren de Lima   $3.7 B  Brazil
# 866                    Franco Bittar Garcia   $3.5 B  Brazil
# 988           Camilla de Godoy Bueno Grossi   $3.1 B  Brazil
# 1011                   Pedro de Godoy Bueno     $3 B  Brazil
# 1074                           Walter Faria   $2.9 B  Brazil
# 1066                        Joesley Batista   $2.9 B  Brazil
# ...

# %%
bil[bil.Country.isin(["Peru","Argentina","Mexico","Ecuador","Colombia"])].sort_values(["NetWorth"], ascending=False)
# Out:
#                                         Name NetWorth    Country  \
# 254      Alberto Bailleres Gonzalez & family   $9.2 B     Mexico
# 370   Juan Francisco Beckmann Vidal & family     $7 B     Mexico
# 15                 Carlos Slim Helu & family  $62.8 B     Mexico
# 441                          Marcos Galperin   $6.1 B  Argentina
# 475   Maria Asuncion Aramburuzabala & family   $5.8 B     Mexico
# 532                  Carlos Rodriguez-Pastor   $5.3 B       Peru
# 547                              David Velez   $5.2 B   Colombia
# 752          Beatriz Davila de Santo Domingo   $3.9 B   Colombia
# 781                     Jaime Gilinski Bacal   $3.8 B   Colombia
# 927                     Alejandro Bulgheroni   $3.3 B  Argentina
# 989          Antonio Del Valle Ruiz & family   $3.1 B     Mexico
# 60       German Larrea Mota Velasco & family  $25.9 B     Mexico
# 1336         Gregorio Perez Companc & family   $2.4 B  Argentina
# ...

# %%
bil.Country.value_counts()
# Out:
# United States           724
# China                   626
# India                   140
# Germany                 136
# Russia                  118
#                        ...
# Eswatini (Swaziland)      1
# Oman                      1
# St. Kitts and Nevis       1
# Guernsey                  1
# Venezuela                 1
# Name: Country, Length: 70, dtype: int64

# %%
import plotly.express as px

# %%
px.histogram(bil.Country).update_xaxes(categoryorder="total descending")
# Out:
# <div>                            <div id="a3631794-6249-46f1-b49b-93fbcdbfbd48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3631794-6249-46f1-b49b-93fbcdbfbd48")) {                    Plotly.newPlot(                        "a3631794-6249-46f1-b49b-93fbcdbfbd48",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=Country<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Country", "marker": {"color": "#636efa"}, "name": "Country", "offsetgroup": "Country", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["United States", "United States", "France", "United States", "United States", "United States", "United States", "United States", "United States", "India", "Spain", "France",
# ...

# %%
bil[bil.Country=="Peru"].sort_values("NetWorth",ascending=False)
# Out:
#                              Name NetWorth Country           Source  Rank
# 532       Carlos Rodriguez-Pastor   $5.3 B    Peru          finance   529
# 2225     Vito Rodriguez Rodriguez   $1.4 B    Peru   processed milk  2141
# 2273  Ana Maria Brescia Cafferata   $1.3 B    Peru  mining, banking  2263
# 2300           Eduardo Hochschild   $1.3 B    Peru           mining  2263
# 2529     Eduardo Belmont Anderson   $1.1 B    Peru        cosmetics  2524
# 2722    Jorge Rodriguez Rodriguez     $1 B    Peru   processed milk  2674

# %%
bil[bil.Country=="United Kingdom"].sort_values("NetWorth",ascending=False)
# Out:
#                                  Name NetWorth         Country  \
# 233                       James Dyson   $9.7 B  United Kingdom
# 252         Ian & Richard Livingstone   $9.3 B  United Kingdom
# 310          Anthony Bamford & family   $7.9 B  United Kingdom
# 324                      David Reuben   $7.7 B  United Kingdom
# 325                      Simon Reuben   $7.7 B  United Kingdom
# 405                     Denise Coates   $6.5 B  United Kingdom
# 473                  Christopher Hohn   $5.9 B  United Kingdom
# 486                     Andrew Currie   $5.7 B  United Kingdom
# 491                        John Reece   $5.7 B  United Kingdom
# 501                      Clive Calder   $5.5 B  United Kingdom
# 577                         Joe Lewis   $4.9 B  United Kingdom
# 589                   Richard Branson   $4.8 B  United Kingdom
# 688                  Peter Hargreaves   $4.2 B  United Kingdom
# 710           Laurence Graff & family   $4.1 B  United Kingdom
# ...
